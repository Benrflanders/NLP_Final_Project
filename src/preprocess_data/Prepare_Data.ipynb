# %%
from load_data import *
load_and_process_data()
# Out:
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/274.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/274.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/13.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/7.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/21.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/21.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/313.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/313.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/258.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/271.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/8.
# copied from: /home/brf97486/finalProject/enron_data/maildir/holst-k/inbox/113.
# ...
