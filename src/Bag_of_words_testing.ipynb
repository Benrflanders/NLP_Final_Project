# %%
from nltk.corpus import opinion_lexicon
from nltk.stem import WordNetLemmatizer
from nltk.probability import ConditionalFreqDist
from nltk.probability import ConditionalProbDist, ELEProbDist #71.50 training accuracy
from nltk.probability import LaplaceProbDist #71.90% training accuracy

import random
import nltk
import numpy as np

from Models import LoadAndTrainModels

def sentiment_feature(word):
	return {'word': word}

def printProbabilitiesFromLogProb(prob_classify_dict):
    positive = prob_classify_dict["positive"]
    negative = prob_classify_dict["negative"]

    print("positive negative log: ", positive)
    print("negative negative log: ", negative)
    
    probs = np.exp([positive, negative])/np.exp([positive, negative]).sum()
    print("positive probability: ", probs[0])
    print("negative probability: ", probs[1])
    
def getProbabilitiesFromLogProb(prob_classify_dict):
    positive = prob_classify_dict["positive"]
    negative = prob_classify_dict["negative"]
    
    probs = np.exp([positive, negative])/np.exp([positive, negative]).sum()
    
    return(probs)

# %%
lemmatizer = WordNetLemmatizer()
    
text = opinion_lexicon

# %%
positive_words = ([(lemmatizer.lemmatize(word=word), 'positive') for word in text.positive()])
negative_words = ([(lemmatizer.lemmatize(word=word), 'negative') for word in text.negative()])

labeled_words = positive_words + negative_words

# %%
random.shuffle(labeled_words)

# %%
featuresets = [(sentiment_feature(n), sentiment) for (n, sentiment) in labeled_words]
    
train_amnt = int(len(featuresets)*.8) #80% train data; 20% test data
train_data = featuresets[:train_amnt]
test_data = featuresets[train_amnt:]
assert len(train_data) == train_amnt

# %%
featuresets
# Out:
# [({'word': 'flareups'}, 'negative'),
#  ({'word': 'lackadaisical'}, 'negative'),
#  ({'word': 'vile'}, 'negative'),
#  ({'word': 'wobble'}, 'negative'),
#  ({'word': 'inelegant'}, 'negative'),
#  ({'word': 'blind'}, 'negative'),
#  ({'word': 'deceptively'}, 'negative'),
#  ({'word': 'irreformable'}, 'negative'),
#  ({'word': 'temptingly'}, 'positive'),
#  ({'word': 'ominous'}, 'negative'),
#  ({'word': 'inexperience'}, 'negative'),
#  ({'word': 'insurrection'}, 'negative'),
#  ({'word': 'dazzle'}, 'positive'),
#  ({'word': 'entanglement'}, 'negative'),
#  ({'word': 'irrelevance'}, 'negative'),
#  ({'word': 'tenacity'}, 'positive'),
#  ({'word': 'dizzing'}, 'negative'),
#  ({'word': 'insignificance'}, 'negative'),
#  ({'word': 'expeditiously'}, 'positive'),
#  ({'word': 'crisis'}, 'negative'),
#  ({'word': 'improvement'}, 'positive'),
#  ({'word': 'upliftingly'}, 'positive'),
#  ({'word': 'trustingly'}, 'positive'),
#  ({'word': 'hazard'}, 'negative'),
#  ({'word': 'revolutionize'}, 'positive'),
#  ({'word': 'cancer'}, 'negative'),
#  ({'word': 'annihilation'}, 'negative'),
#  ({'word': 'clunky'}, 'negative'),
#  ({'word': 'get-rich'}, 'negative'),
#  ({'word': 'condescension'}, 'negative'),
#  ({'word': 'skeptically'}, 'negative'),
#  ({'word': 'crack'}, 'negative'),
#  ({'word': 'disadvantaged'}, 'negative'),
#  ({'word': 'shamefully'}, 'negative'),
#  ({'word': 'threaten'}, 'negative'),
#  ({'word': 'sinisterly'}, 'negative'),
#  ({'word': 'celebrated'}, 'positive'),
#  ({'word': 'crumpled'}, 'negative'),
#  ({'word': 'plea'}, 'negative'),
#  ({'word': 'confused'}, 'negative'),
#  ({'word': 'chastise'}, 'negative'),
#  ({'word': 'plagiarize'}, 'negative'),
#  ({'word': 'irrecoverably'}, 'negative'),
#  ({'word': 'crisper'}, 'positive'),
#  ({'word': 'graft'}, 'negative'),
#  ({'word': 'streaky'}, 'negative'),
#  ({'word': 'painfull'}, 'negative'),
#  ({'word': 'detrimental'}, 'negative'),
#  ({'word': 'sarcastically'}, 'negative'),
#  ({'word': 'clique'}, 'negative'),
#  ({'word': 'tenaciously'}, 'positive'),
#  ({'word': 'incoherently'}, 'negative'),
#  ({'word': 'spoilage'}, 'negative'),
#  ({'word': 'misery'}, 'negative'),
#  ({'word': 'spurn'}, 'negative'),
#  ({'word': 'nauseatingly'}, 'negative'),
#  ({'word': 'dodgey'}, 'negative'),
#  ({'word': 'meaningless'}, 'negative'),
#  ({'word': 'uplift'}, 'positive'),
#  ({'word': 'gallingly'}, 'negative'),
#  ({'word': 'absurdity'}, 'negative'),
#  ({'word': 'monstrosity'}, 'negative'),
#  ({'word': 'unjustifiable'}, 'negative'),
#  ({'word': 'blossom'}, 'positive'),
#  ({'word': 'thrifty'}, 'positive'),
#  ({'word': 'unreal'}, 'positive'),
#  ({'word': 'nebulously'}, 'negative'),
#  ({'word': 'awesomely'}, 'positive'),
#  ({'word': 'recklessly'}, 'negative'),
#  ({'word': 'renown'}, 'positive'),
#  ({'word': 'choppy'}, 'negative'),
#  ({'word': 'terror'}, 'negative'),
#  ({'word': 'belittle'}, 'negative'),
#  ({'word': 'jagged'}, 'negative'),
#  ({'word': 'educated'}, 'positive'),
#  ({'word': 'scratchy'}, 'negative'),
#  ({'word': 'adverse'}, 'negative'),
#  ({'word': 'immature'}, 'negative'),
#  ({'word': 'unipolar'}, 'negative'),
#  ({'word': 'poeticize'}, 'positive'),
#  ({'word': 'vibrates'}, 'negative'),
#  ({'word': 'soreness'}, 'negative'),
#  ({'word': 'effusiveness'}, 'positive'),
#  ({'word': 'ardently'}, 'positive'),
#  ({'word': 'pep'}, 'positive'),
#  ({'word': 'favorited'}, 'positive'),
#  ({'word': 'seriousness'}, 'negative'),
#  ({'word': 'reachable'}, 'positive'),
#  ({'word': 'desolately'}, 'negative'),
#  ({'word': 'erase'}, 'negative'),
#  ({'word': 'dismalness'}, 'negative'),
#  ({'word': 'distraughtness'}, 'negative'),
#  ({'word': 'mesmerizing'}, 'positive'),
#  ({'word': 'catastrophe'}, 'negative'),
#  ({'word': 'disloyalty'}, 'negative'),
#  ({'word': 'unruly'}, 'negative'),
#  ({'word': 'unobserved'}, 'negative'),
#  ({'word': 'nasty'}, 'negative'),
#  ({'word': 'grateful'}, 'positive'),
#  ({'word': 'boundless'}, 'positive'),
#  ({'word': 'menacing'}, 'negative'),
#  ({'word': 'mobster'}, 'negative'),
#  ({'word': 'implausibly'}, 'negative'),
#  ({'word': 'exceeds'}, 'positive'),
#  ({'word': 'squash'}, 'negative'),
#  ({'word': 'fault'}, 'negative'),
#  ({'word': 'mortify'}, 'negative'),
#  ({'word': 'struck'}, 'negative'),
#  ({'word': 'illuminating'}, 'positive'),
#  ({'word': 'conscons'}, 'negative'),
#  ({'word': 'bullying'}, 'negative'),
#  ({'word': 'revenge'}, 'negative'),
#  ({'word': 'zapped'}, 'negative'),
#  ({'word': 'furor'}, 'negative'),
#  ({'word': 'pamper'}, 'positive'),
#  ({'word': 'strife'}, 'negative'),
#  ({'word': 'excuse'}, 'negative'),
#  ({'word': 'tyrannically'}, 'negative'),
#  ({'word': 'untimely'}, 'negative'),
#  ({'word': 'sharper'}, 'positive'),
#  ({'word': 'eschew'}, 'negative'),
#  ({'word': 'bleakness'}, 'negative'),
#  ({'word': 'rejuvenate'}, 'positive'),
#  ({'word': 'askance'}, 'negative'),
#  ({'word': 'wasting'}, 'negative'),
#  ({'word': 'gainsayer'}, 'negative'),
#  ({'word': 'suffocate'}, 'negative'),
#  ({'word': 'hissing'}, 'negative'),
#  ({'word': 'rockstars'}, 'positive'),
#  ({'word': 'inevitable'}, 'negative'),
#  ({'word': 'overwhelms'}, 'negative'),
#  ({'word': 'amply'}, 'positive'),
#  ({'word': 'overstatement'}, 'negative'),
#  ({'word': 'deluge'}, 'negative'),
#  ({'word': 'self-sufficiency'}, 'positive'),
#  ({'word': 'eyecatching'}, 'positive'),
#  ({'word': 'setback'}, 'negative'),
#  ({'word': 'zenith'}, 'positive'),
#  ({'word': 'indolent'}, 'negative'),
#  ({'word': 'strongest'}, 'positive'),
#  ({'word': 'unviewable'}, 'negative'),
#  ({'word': 'defeated'}, 'positive'),
#  ({'word': 'elatedly'}, 'positive'),
#  ({'word': 'notorious'}, 'negative'),
#  ({'word': 'foolhardy'}, 'negative'),
#  ({'word': 'impudent'}, 'negative'),
#  ({'word': 'debilitate'}, 'negative'),
#  ({'word': 'maniacal'}, 'negative'),
#  ({'word': 'indigent'}, 'negative'),
#  ({'word': 'somber'}, 'negative'),
#  ({'word': 'ruffian'}, 'negative'),
#  ({'word': 'hatefulness'}, 'negative'),
#  ({'word': 'disagreed'}, 'negative'),
#  ({'word': 'downgrade'}, 'negative'),
#  ({'word': 'relentless'}, 'negative'),
#  ({'word': 'deviousness'}, 'negative'),
#  ({'word': 'sensibly'}, 'positive'),
#  ({'word': 'vomiting'}, 'negative'),
#  ({'word': 'disreputable'}, 'negative'),
#  ({'word': 'frazzle'}, 'negative'),
#  ({'word': 'jerk'}, 'negative'),
#  ({'word': 'buzzing'}, 'negative'),
#  ({'word': 'sarcastic'}, 'negative'),
#  ({'word': 'rejuvenated'}, 'positive'),
#  ({'word': 'beset'}, 'negative'),
#  ({'word': 'inteferes'}, 'negative'),
#  ({'word': 'subsidized'}, 'positive'),
#  ({'word': 'pan'}, 'negative'),
#  ({'word': 'ultimatum'}, 'negative'),
#  ({'word': 'shimmer'}, 'negative'),
#  ({'word': 'miserably'}, 'negative'),
#  ({'word': 'shameful'}, 'negative'),
#  ({'word': 'pauper'}, 'negative'),
#  ({'word': 'suffered'}, 'negative'),
#  ({'word': 'sullen'}, 'negative'),
#  ({'word': 'spiritual'}, 'positive'),
#  ({'word': 'inextricably'}, 'negative'),
#  ({'word': 'fruitless'}, 'negative'),
#  ({'word': 'heretical'}, 'negative'),
#  ({'word': 'fastest-growing'}, 'positive'),
#  ({'word': 'cheer'}, 'positive'),
#  ({'word': 'fright'}, 'negative'),
#  ({'word': 'hestitant'}, 'negative'),
#  ({'word': 'disturbingly'}, 'negative'),
#  ({'word': 'elan'}, 'positive'),
#  ({'word': 'reprovingly'}, 'negative'),
#  ({'word': 'treason'}, 'negative'),
#  ({'word': 'trickery'}, 'negative'),
#  ({'word': 'selective'}, 'positive'),
#  ({'word': 'glory'}, 'positive'),
#  ({'word': 'elimination'}, 'negative'),
#  ({'word': 'exceedingly'}, 'positive'),
#  ({'word': 'negligent'}, 'negative'),
#  ({'word': 'spank'}, 'negative'),
#  ({'word': 'underling'}, 'negative'),
#  ({'word': 'amazes'}, 'positive'),
#  ({'word': 'flourishing'}, 'positive'),
#  ({'word': 'freeze'}, 'negative'),
#  ({'word': 'stink'}, 'negative'),
#  ({'word': 'oblique'}, 'negative'),
#  ({'word': 'petrified'}, 'negative'),
#  ({'word': 'moribund'}, 'negative'),
#  ({'word': 'loss'}, 'negative'),
#  ({'word': 'imprecise'}, 'negative'),
#  ({'word': 'intransigent'}, 'negative'),
#  ({'word': 'delude'}, 'negative'),
#  ({'word': 'monumental'}, 'positive'),
#  ({'word': 'torrent'}, 'negative'),
#  ({'word': 'paltry'}, 'negative'),
#  ({'word': 'incompliant'}, 'negative'),
#  ({'word': 'upseting'}, 'negative'),
#  ({'word': 'damnation'}, 'negative'),
#  ({'word': 'unrest'}, 'negative'),
#  ({'word': 'bonus'}, 'positive'),
#  ({'word': 'drought'}, 'negative'),
#  ({'word': 'pauper'}, 'negative'),
#  ({'word': 'gratify'}, 'positive'),
#  ({'word': 'benifits'}, 'positive'),
#  ({'word': 'problem-solver'}, 'positive'),
#  ({'word': 'so-cal'}, 'negative'),
#  ({'word': 'crippling'}, 'negative'),
#  ({'word': 'scaly'}, 'negative'),
#  ({'word': 'flair'}, 'negative'),
#  ({'word': 'incommensurate'}, 'negative'),
#  ({'word': 'unprepared'}, 'negative'),
#  ({'word': 'disastrously'}, 'negative'),
#  ({'word': 'feisty'}, 'positive'),
#  ({'word': 'slowed'}, 'negative'),
#  ({'word': 'invalidity'}, 'negative'),
#  ({'word': 'unreasonably'}, 'negative'),
#  ({'word': 'autocrat'}, 'negative'),
#  ({'word': 'deceiver'}, 'negative'),
#  ({'word': 'wariness'}, 'negative'),
#  ({'word': 'heroize'}, 'positive'),
#  ({'word': 'obsolete'}, 'negative'),
#  ({'word': 'sourly'}, 'negative'),
#  ({'word': 'stumble'}, 'negative'),
#  ({'word': 'byzantine'}, 'negative'),
#  ({'word': 'beckoning'}, 'positive'),
#  ({'word': 'freaking'}, 'negative'),
#  ({'word': 'hedge'}, 'negative'),
#  ({'word': 'refuting'}, 'negative'),
#  ({'word': 'unorthodoxy'}, 'negative'),
#  ({'word': 'reverently'}, 'positive'),
#  ({'word': 'agony'}, 'negative'),
#  ({'word': 'cuteness'}, 'positive'),
#  ({'word': 'evasion'}, 'negative'),
#  ({'word': 'wellbeing'}, 'positive'),
#  ({'word': 'frenetically'}, 'negative'),
#  ({'word': 'simplified'}, 'positive'),
#  ({'word': 'contaminate'}, 'negative'),
#  ({'word': 'disgusting'}, 'negative'),
#  ({'word': 'despise'}, 'negative'),
#  ({'word': 'obsessiveness'}, 'negative'),
#  ({'word': 'smarter'}, 'positive'),
#  ({'word': 'fissure'}, 'negative'),
#  ({'word': 'stutter'}, 'negative'),
#  ({'word': 'stifling'}, 'negative'),
#  ({'word': 'abominate'}, 'negative'),
#  ({'word': 'bemoan'}, 'negative'),
#  ({'word': 'nervousness'}, 'negative'),
#  ({'word': 'spectacularly'}, 'positive'),
#  ({'word': 'contemptible'}, 'negative'),
#  ({'word': 'benevolent'}, 'positive'),
#  ({'word': 'beneficial'}, 'positive'),
#  ({'word': 'left-leaning'}, 'negative'),
#  ({'word': 'overbearingly'}, 'negative'),
#  ({'word': 'crippled'}, 'negative'),
#  ({'word': 'disbelieve'}, 'negative'),
#  ({'word': 'involuntarily'}, 'negative'),
#  ({'word': 'hard'}, 'negative'),
#  ({'word': 'dependably'}, 'positive'),
#  ({'word': 'curse'}, 'negative'),
#  ({'word': 'ultra-crisp'}, 'positive'),
#  ({'word': 'debauch'}, 'negative'),
#  ({'word': 'mesmerizingly'}, 'positive'),
#  ({'word': 'fainthearted'}, 'negative'),
#  ({'word': 'obnoxiously'}, 'negative'),
#  ({'word': 'consummate'}, 'positive'),
#  ({'word': 'buggy'}, 'negative'),
#  ({'word': 'sillily'}, 'negative'),
#  ({'word': 'hooray'}, 'positive'),
#  ({'word': 'prejudicial'}, 'negative'),
#  ({'word': 'angelic'}, 'positive'),
#  ({'word': 'modern'}, 'positive'),
#  ({'word': 'allergic'}, 'negative'),
#  ({'word': 'downer'}, 'negative'),
#  ({'word': 'dilapidated'}, 'negative'),
#  ({'word': 'embarrass'}, 'negative'),
#  ({'word': 'indiscernible'}, 'negative'),
#  ({'word': 'fatalistically'}, 'negative'),
#  ({'word': 'defeat'}, 'positive'),
#  ({'word': 'nonresponsive'}, 'negative'),
#  ({'word': 'appreciates'}, 'positive'),
#  ({'word': 'enticing'}, 'positive'),
#  ({'word': 'promptly'}, 'positive'),
#  ({'word': 'dissonance'}, 'negative'),
#  ({'word': 'distains'}, 'negative'),
#  ({'word': 'deformed'}, 'negative'),
#  ({'word': 'danger'}, 'negative'),
#  ({'word': 'dazzled'}, 'positive'),
#  ({'word': 'infirm'}, 'negative'),
#  ({'word': 'recklessness'}, 'negative'),
#  ({'word': 'satirical'}, 'negative'),
#  ({'word': 'dismal'}, 'negative'),
#  ({'word': 'niggles'}, 'negative'),
#  ({'word': 'chatter'}, 'negative'),
#  ({'word': 'oversight'}, 'negative'),
#  ({'word': 'irresistibly'}, 'positive'),
#  ({'word': 'tenacious'}, 'positive'),
#  ({'word': 'inequity'}, 'negative'),
#  ({'word': 'implicate'}, 'negative'),
#  ({'word': 'fast-paced'}, 'positive'),
#  ({'word': 'comical'}, 'negative'),
#  ({'word': 'altruistically'}, 'positive'),
#  ({'word': 'nightmarish'}, 'negative'),
#  ({'word': 'unnerved'}, 'negative'),
#  ({'word': 'bankrupt'}, 'negative'),
#  ({'word': 'prestige'}, 'positive'),
#  ({'word': 'underpaid'}, 'negative'),
#  ({'word': 'distrusting'}, 'negative'),
#  ({'word': 'disillusioned'}, 'negative'),
#  ({'word': 'mightily'}, 'positive'),
#  ({'word': 'tank'}, 'negative'),
#  ({'word': 'mispronounces'}, 'negative'),
#  ({'word': 'monumentally'}, 'positive'),
#  ({'word': 'craze'}, 'negative'),
#  ({'word': 'raked'}, 'negative'),
#  ({'word': 'frustration'}, 'negative'),
#  ({'word': 'excites'}, 'positive'),
#  ({'word': 'unwelcome'}, 'negative'),
#  ({'word': 'conflict'}, 'negative'),
#  ({'word': 'bleeding'}, 'negative'),
#  ({'word': 'gratifyingly'}, 'positive'),
#  ({'word': 'senile'}, 'negative'),
#  ({'word': 'reaffirm'}, 'positive'),
#  ({'word': 'assurance'}, 'positive'),
#  ({'word': 'traumatized'}, 'negative'),
#  ({'word': 'unexplained'}, 'negative'),
#  ({'word': 'absurdness'}, 'negative'),
#  ({'word': 'fabricate'}, 'negative'),
#  ({'word': 'oddity'}, 'negative'),
#  ({'word': 'intolerablely'}, 'negative'),
#  ({'word': 'magnificent'}, 'positive'),
#  ({'word': 'brainy'}, 'positive'),
#  ({'word': 'hostility'}, 'negative'),
#  ({'word': 'cruelest'}, 'negative'),
#  ({'word': 'sick'}, 'negative'),
#  ({'word': 'cripple'}, 'negative'),
#  ({'word': 'repressive'}, 'negative'),
#  ({'word': 'bulkyness'}, 'negative'),
#  ({'word': 'lapse'}, 'negative'),
#  ({'word': 'wise'}, 'positive'),
#  ({'word': 'ineffectual'}, 'negative'),
#  ({'word': 'attentive'}, 'positive'),
#  ({'word': 'felonious'}, 'negative'),
#  ({'word': 'slumpping'}, 'negative'),
#  ({'word': 'nicer'}, 'positive'),
#  ({'word': 'saving'}, 'positive'),
#  ({'word': 'taut'}, 'negative'),
#  ({'word': 'handier'}, 'positive'),
#  ({'word': 'corrosive'}, 'negative'),
#  ({'word': 'infidel'}, 'negative'),
#  ({'word': 'thrive'}, 'positive'),
#  ({'word': 'maneuverable'}, 'positive'),
#  ({'word': 'sermonize'}, 'negative'),
#  ({'word': 'youthful'}, 'positive'),
#  ({'word': 'oversize'}, 'negative'),
#  ({'word': 'discourteous'}, 'negative'),
#  ({'word': 'pander'}, 'negative'),
#  ({'word': 'vibrated'}, 'negative'),
#  ({'word': 'punch'}, 'negative'),
#  ({'word': 'aggrieved'}, 'negative'),
#  ({'word': 'irrepressible'}, 'negative'),
#  ({'word': 'hegemonism'}, 'negative'),
#  ({'word': 'cuplrit'}, 'negative'),
#  ({'word': 'appreciated'}, 'positive'),
#  ({'word': 'incautious'}, 'negative'),
#  ({'word': 'loathly'}, 'negative'),
#  ({'word': 'bumped'}, 'negative'),
#  ({'word': 'unfit'}, 'negative'),
#  ({'word': 'adventurous'}, 'positive'),
#  ({'word': 'ample'}, 'positive'),
#  ({'word': 'distraughtly'}, 'negative'),
#  ({'word': 'feverish'}, 'negative'),
#  ({'word': 'fall'}, 'negative'),
#  ({'word': 'rumple'}, 'negative'),
#  ({'word': 'harmed'}, 'negative'),
#  ({'word': 'falter'}, 'negative'),
#  ({'word': 'impetuously'}, 'negative'),
#  ({'word': 'tin-y'}, 'negative'),
#  ({'word': 'displeasing'}, 'negative'),
#  ({'word': 'non-violent'}, 'positive'),
#  ({'word': 'razor-sharp'}, 'positive'),
#  ({'word': 'fathomless'}, 'negative'),
#  ({'word': 'depravedly'}, 'negative'),
#  ({'word': 'haywire'}, 'negative'),
#  ({'word': 'superstition'}, 'negative'),
#  ({'word': 'inspire'}, 'positive'),
#  ({'word': 'exterminate'}, 'negative'),
#  ({'word': 'regret'}, 'negative'),
#  ({'word': 'offender'}, 'negative'),
#  ({'word': 'pre-eminent'}, 'positive'),
#  ({'word': 'randomly'}, 'negative'),
#  ({'word': 'glamorous'}, 'positive'),
#  ({'word': 'elegantly'}, 'positive'),
#  ({'word': 'pretentiously'}, 'negative'),
#  ({'word': 'deceptive'}, 'negative'),
#  ({'word': 'encouragement'}, 'positive'),
#  ({'word': 'rumor'}, 'negative'),
#  ({'word': 'desiccated'}, 'negative'),
#  ({'word': 'immaculate'}, 'positive'),
#  ({'word': 'injurious'}, 'negative'),
#  ({'word': 'ignoble'}, 'negative'),
#  ({'word': 'terrible'}, 'negative'),
#  ({'word': 'considerate'}, 'positive'),
#  ({'word': 'bowdlerize'}, 'negative'),
#  ({'word': 'ineloquently'}, 'negative'),
#  ({'word': 'rewarding'}, 'positive'),
#  ({'word': 'laid-off'}, 'negative'),
#  ({'word': 'wrip'}, 'negative'),
#  ({'word': 'enchanting'}, 'positive'),
#  ({'word': 'bleeds'}, 'negative'),
#  ({'word': 'vengefully'}, 'negative'),
#  ({'word': 'unreliable'}, 'negative'),
#  ({'word': 'advantage'}, 'positive'),
#  ({'word': 'perplex'}, 'negative'),
#  ({'word': 'smudging'}, 'negative'),
#  ({'word': 'astutely'}, 'positive'),
#  ({'word': 'exceeded'}, 'positive'),
#  ({'word': 'incompetent'}, 'negative'),
#  ({'word': 'protest'}, 'negative'),
#  ({'word': 'cheaply'}, 'negative'),
#  ({'word': 'retardedness'}, 'negative'),
#  ({'word': 'fractiously'}, 'negative'),
#  ({'word': 'disapprove'}, 'negative'),
#  ({'word': 'civility'}, 'positive'),
#  ({'word': 'cheapest'}, 'positive'),
#  ({'word': 'pillory'}, 'negative'),
#  ({'word': 'mischievously'}, 'negative'),
#  ({'word': 'loneliness'}, 'negative'),
#  ({'word': 'hassle'}, 'negative'),
#  ({'word': 'declaim'}, 'negative'),
#  ({'word': 'lyrical'}, 'positive'),
#  ({'word': 'acridness'}, 'negative'),
#  ({'word': 'smilingly'}, 'positive'),
#  ({'word': 'knotted'}, 'negative'),
#  ({'word': 'laudably'}, 'positive'),
#  ({'word': 'friction'}, 'negative'),
#  ({'word': 'desititute'}, 'negative'),
#  ({'word': 'screw-up'}, 'negative'),
#  ({'word': 'dreadfully'}, 'negative'),
#  ({'word': 'brainwash'}, 'negative'),
#  ({'word': 'skillful'}, 'positive'),
#  ({'word': 'unhappy'}, 'negative'),
#  ({'word': 'ebullience'}, 'positive'),
#  ({'word': 'villainous'}, 'negative'),
#  ({'word': 'blindside'}, 'negative'),
#  ({'word': 'prosperity'}, 'positive'),
#  ({'word': 'indulgent'}, 'positive'),
#  ({'word': 'fascination'}, 'positive'),
#  ({'word': 'appallingly'}, 'negative'),
#  ({'word': 'animosity'}, 'negative'),
#  ({'word': 'embroiled'}, 'negative'),
#  ({'word': 'peculiarly'}, 'negative'),
#  ({'word': 'trauma'}, 'negative'),
#  ({'word': 'smelly'}, 'negative'),
#  ({'word': 'heretic'}, 'negative'),
#  ({'word': 'recalcitrant'}, 'negative'),
#  ({'word': 'precariously'}, 'negative'),
#  ({'word': 'trusting'}, 'positive'),
#  ({'word': 'logical'}, 'positive'),
#  ({'word': 'wonderous'}, 'positive'),
#  ({'word': 'protracted'}, 'negative'),
#  ({'word': 'dubiously'}, 'negative'),
#  ({'word': 'overwhelm'}, 'negative'),
#  ({'word': 'despotic'}, 'negative'),
#  ({'word': 'retractable'}, 'positive'),
#  ({'word': 'objection'}, 'negative'),
#  ({'word': 'drawback'}, 'negative'),
#  ({'word': 'ripoff'}, 'negative'),
#  ({'word': 'pig'}, 'negative'),
#  ({'word': 'furious'}, 'negative'),
#  ({'word': 'horrendous'}, 'negative'),
#  ({'word': 'thumbs-down'}, 'negative'),
#  ({'word': 'fraught'}, 'negative'),
#  ({'word': 'aborted'}, 'negative'),
#  ({'word': 'jolly'}, 'positive'),
#  ({'word': 'striking'}, 'positive'),
#  ({'word': 'ingrate'}, 'negative'),
#  ({'word': 'shroud'}, 'negative'),
#  ({'word': 'outdo'}, 'positive'),
#  ({'word': 'shadowy'}, 'negative'),
#  ({'word': 'lackey'}, 'negative'),
#  ({'word': 'graciousness'}, 'positive'),
#  ({'word': 'detracted'}, 'negative'),
#  ({'word': 'radicalization'}, 'negative'),
#  ({'word': 'entrap'}, 'negative'),
#  ({'word': 'upgradeable'}, 'positive'),
#  ({'word': 'revengefully'}, 'negative'),
#  ({'word': 'wripped'}, 'negative'),
#  ({'word': 'unfavorable'}, 'negative'),
#  ({'word': 'marginal'}, 'negative'),
#  ({'word': 'full-blown'}, 'negative'),
#  ({'word': 'damned'}, 'negative'),
#  ({'word': 'illuminati'}, 'positive'),
#  ({'word': 'interrupt'}, 'negative'),
#  ({'word': 'inhuman'}, 'negative'),
#  ({'word': 'handsomely'}, 'positive'),
#  ({'word': 'cheerful'}, 'positive'),
#  ({'word': 'scrap'}, 'negative'),
#  ({'word': 'forswear'}, 'negative'),
#  ({'word': 'effortless'}, 'positive'),
#  ({'word': 'affordably'}, 'positive'),
#  ({'word': 'crumbling'}, 'negative'),
#  ({'word': 'handily'}, 'positive'),
#  ({'word': 'irate'}, 'negative'),
#  ({'word': 'slump'}, 'negative'),
#  ({'word': 'convient'}, 'positive'),
#  ({'word': 'dissing'}, 'negative'),
#  ({'word': 'hard-line'}, 'negative'),
#  ({'word': 'smouldering'}, 'negative'),
#  ({'word': 'stutter'}, 'negative'),
#  ({'word': 'unimportant'}, 'negative'),
#  ({'word': 'infringement'}, 'negative'),
#  ({'word': 'fame'}, 'positive'),
#  ({'word': 'grouse'}, 'negative'),
#  ({'word': 'impoverished'}, 'negative'),
#  ({'word': 'amity'}, 'positive'),
#  ({'word': 'hypocrite'}, 'negative'),
#  ({'word': 'mindlessly'}, 'negative'),
#  ({'word': 'quarrelsome'}, 'negative'),
#  ({'word': 'dust'}, 'negative'),
#  ({'word': 'ill-used'}, 'negative'),
#  ({'word': 'ill-designed'}, 'negative'),
#  ({'word': 'suitable'}, 'positive'),
#  ({'word': 'available'}, 'positive'),
#  ({'word': 'enviable'}, 'positive'),
#  ({'word': 'confuse'}, 'negative'),
#  ({'word': 'whoa'}, 'positive'),
#  ({'word': 'weariness'}, 'negative'),
#  ({'word': 'restriction'}, 'negative'),
#  ({'word': 'tantalize'}, 'positive'),
#  ({'word': 'deference'}, 'positive'),
#  ({'word': 'equivocal'}, 'negative'),
#  ({'word': 'criticize'}, 'negative'),
#  ({'word': 'exemplary'}, 'positive'),
#  ({'word': 'repulsively'}, 'negative'),
#  ({'word': 'enticed'}, 'positive'),
#  ({'word': 'famished'}, 'negative'),
#  ({'word': 'enmity'}, 'negative'),
#  ({'word': 'ill-conceived'}, 'negative'),
#  ({'word': 'nice'}, 'positive'),
#  ({'word': 'unwatchable'}, 'negative'),
#  ({'word': 'mocked'}, 'negative'),
#  ({'word': 'affectation'}, 'positive'),
#  ({'word': 'serene'}, 'positive'),
#  ({'word': 'depression'}, 'negative'),
#  ({'word': 'pestilent'}, 'negative'),
#  ({'word': 'annoyance'}, 'negative'),
#  ({'word': 'ill-favored'}, 'negative'),
#  ({'word': 'bias'}, 'negative'),
#  ({'word': 'panicking'}, 'negative'),
#  ({'word': 'strangest'}, 'negative'),
#  ({'word': 'zeal'}, 'positive'),
#  ({'word': 'back-woods'}, 'negative'),
#  ({'word': 'stylishly'}, 'positive'),
#  ({'word': 'patient'}, 'positive'),
#  ({'word': 'gallantly'}, 'positive'),
#  ({'word': 'disgraced'}, 'negative'),
#  ({'word': 'freshest'}, 'positive'),
#  ({'word': 'alienation'}, 'negative'),
#  ({'word': 'lividly'}, 'negative'),
#  ({'word': 'phobic'}, 'negative'),
#  ({'word': 'inconsequential'}, 'negative'),
#  ({'word': 'erudite'}, 'positive'),
#  ({'word': 'pugnacity'}, 'negative'),
#  ({'word': 'famine'}, 'negative'),
#  ({'word': 'imaginary'}, 'negative'),
#  ({'word': 'squabble'}, 'negative'),
#  ({'word': 'joyous'}, 'positive'),
#  ({'word': 'prudent'}, 'positive'),
#  ({'word': 'lethargy'}, 'negative'),
#  ({'word': 'imbalance'}, 'negative'),
#  ({'word': 'disquieting'}, 'negative'),
#  ({'word': 'opinionated'}, 'negative'),
#  ({'word': 'unreachable'}, 'negative'),
#  ({'word': 'coupists'}, 'negative'),
#  ({'word': 'propagandize'}, 'negative'),
#  ({'word': 'dexterous'}, 'positive'),
#  ({'word': 'cuss'}, 'negative'),
#  ({'word': 'overwhelmingly'}, 'negative'),
#  ({'word': 'perturb'}, 'negative'),
#  ({'word': 'oversight'}, 'negative'),
#  ({'word': 'denying'}, 'negative'),
#  ({'word': 'pertinaciously'}, 'negative'),
#  ({'word': 'puzzling'}, 'negative'),
#  ({'word': 'aspersion'}, 'negative'),
#  ({'word': 'hissed'}, 'negative'),
#  ({'word': 'haggle'}, 'negative'),
#  ({'word': 'unaccessible'}, 'negative'),
#  ({'word': 'inestimably'}, 'positive'),
#  ({'word': 'humane'}, 'positive'),
#  ({'word': 'derisively'}, 'negative'),
#  ({'word': 'wasteful'}, 'negative'),
#  ({'word': 'unlamentable'}, 'negative'),
#  ({'word': 'unbearablely'}, 'negative'),
#  ({'word': 'illusion'}, 'negative'),
#  ({'word': 'moron'}, 'negative'),
#  ({'word': 'stain'}, 'negative'),
#  ({'word': 'remission'}, 'positive'),
#  ({'word': 'ameliorate'}, 'positive'),
#  ({'word': 'chaos'}, 'negative'),
#  ({'word': 'hothouse'}, 'negative'),
#  ({'word': 'headache'}, 'negative'),
#  ({'word': 'uproarously'}, 'negative'),
#  ({'word': 'fleed'}, 'negative'),
#  ({'word': 'unsure'}, 'negative'),
#  ({'word': 'intolerable'}, 'negative'),
#  ({'word': 'expunge'}, 'negative'),
#  ({'word': 'wrongful'}, 'negative'),
#  ({'word': 'insightfully'}, 'positive'),
#  ({'word': 'bump'}, 'negative'),
#  ({'word': 'gainsay'}, 'negative'),
#  ({'word': 'calamitous'}, 'negative'),
#  ({'word': 'disgracefully'}, 'negative'),
#  ({'word': 'trump'}, 'positive'),
#  ({'word': 'revolutionary'}, 'positive'),
#  ({'word': 'brute'}, 'negative'),
#  ({'word': 'marvellous'}, 'positive'),
#  ({'word': 'shamelessly'}, 'negative'),
#  ({'word': 'dissenter'}, 'negative'),
#  ({'word': 'hairloss'}, 'negative'),
#  ({'word': 'heroically'}, 'positive'),
#  ({'word': 'relapse'}, 'negative'),
#  ({'word': 'predatory'}, 'negative'),
#  ({'word': 'stump'}, 'negative'),
#  ({'word': 'nettlesome'}, 'negative'),
#  ({'word': 'wealthy'}, 'positive'),
#  ({'word': 'breakdown'}, 'negative'),
#  ({'word': 'finest'}, 'positive'),
#  ({'word': 'violently'}, 'negative'),
#  ({'word': 'precious'}, 'positive'),
#  ({'word': 'mesmerize'}, 'positive'),
#  ({'word': 'virtue'}, 'positive'),
#  ({'word': 'inhospitality'}, 'negative'),
#  ({'word': 'sloppy'}, 'negative'),
#  ({'word': 'swiftness'}, 'positive'),
#  ({'word': 'blithe'}, 'positive'),
#  ({'word': 'feeble'}, 'negative'),
#  ({'word': 'beneficiary'}, 'positive'),
#  ({'word': 'infected'}, 'negative'),
#  ({'word': 'boredom'}, 'negative'),
#  ({'word': 'uneventful'}, 'negative'),
#  ({'word': 'faithful'}, 'positive'),
#  ({'word': 'hectic'}, 'negative'),
#  ({'word': 'grotesque'}, 'negative'),
#  ({'word': 'corruption'}, 'negative'),
#  ({'word': 'disorder'}, 'negative'),
#  ({'word': 'dissonantly'}, 'negative'),
#  ({'word': 'detracting'}, 'negative'),
#  ({'word': 'insidious'}, 'negative'),
#  ({'word': 'trivialize'}, 'negative'),
#  ({'word': 'traumatically'}, 'negative'),
#  ({'word': 'rightful'}, 'positive'),
#  ({'word': 'speedy'}, 'positive'),
#  ({'word': 'licentious'}, 'negative'),
#  ({'word': 'unkindly'}, 'negative'),
#  ({'word': 'rockstar'}, 'positive'),
#  ({'word': 'disgustful'}, 'negative'),
#  ({'word': 'imprudence'}, 'negative'),
#  ({'word': 'implication'}, 'negative'),
#  ({'word': 'slaughter'}, 'negative'),
#  ({'word': 'distract'}, 'negative'),
#  ({'word': 'substantive'}, 'positive'),
#  ({'word': 'influential'}, 'positive'),
#  ({'word': 'continuity'}, 'positive'),
#  ({'word': 'warp'}, 'negative'),
#  ({'word': 'ridicule'}, 'negative'),
#  ({'word': 'high-quality'}, 'positive'),
#  ({'word': 'thoughtfully'}, 'positive'),
#  ({'word': 'affliction'}, 'negative'),
#  ({'word': 'concerned'}, 'negative'),
#  ({'word': 'totalitarian'}, 'negative'),
#  ({'word': 'irreproachable'}, 'positive'),
#  ({'word': 'accursed'}, 'negative'),
#  ({'word': 'enflame'}, 'negative'),
#  ({'word': 'ridicule'}, 'negative'),
#  ({'word': 'stupendously'}, 'positive'),
#  ({'word': 'imbroglio'}, 'negative'),
#  ({'word': 'inequality'}, 'negative'),
#  ({'word': 'admirable'}, 'positive'),
#  ({'word': 'elevate'}, 'positive'),
#  ({'word': 'chunky'}, 'negative'),
#  ({'word': 'assuredly'}, 'positive'),
#  ({'word': 'surpass'}, 'positive'),
#  ({'word': 'providence'}, 'positive'),
#  ({'word': 'displeasure'}, 'negative'),
#  ({'word': 'stumbled'}, 'negative'),
#  ({'word': 'motley'}, 'negative'),
#  ({'word': 'throbbed'}, 'negative'),
#  ({'word': 'gruesomely'}, 'negative'),
#  ({'word': 'unreasonable'}, 'negative'),
#  ({'word': 'haphazard'}, 'negative'),
#  ({'word': 'irony'}, 'negative'),
#  ({'word': 'keenness'}, 'positive'),
#  ({'word': 'snare'}, 'negative'),
#  ({'word': 'strikingly'}, 'positive'),
#  ({'word': 'exaggeration'}, 'negative'),
#  ({'word': 'recommended'}, 'positive'),
#  ({'word': 'upset'}, 'negative'),
#  ({'word': 'exceptionally'}, 'positive'),
#  ({'word': 'insinuate'}, 'negative'),
#  ({'word': 'phenomenally'}, 'positive'),
#  ({'word': 'fond'}, 'positive'),
#  ({'word': 'inconsiderate'}, 'negative'),
#  ({'word': 'lively'}, 'positive'),
#  ({'word': 'misfortune'}, 'negative'),
#  ({'word': '2-faces'}, 'negative'),
#  ({'word': 'malcontented'}, 'negative'),
#  ({'word': 'repugnance'}, 'negative'),
#  ({'word': 'deny'}, 'negative'),
#  ({'word': 'timid'}, 'negative'),
#  ({'word': 'slut'}, 'negative'),
#  ({'word': 'streamlined'}, 'positive'),
#  ({'word': 'jeeringly'}, 'negative'),
#  ({'word': 'fleeting'}, 'negative'),
#  ({'word': 'disarray'}, 'negative'),
#  ({'word': 'jealousy'}, 'negative'),
#  ({'word': 'heckle'}, 'negative'),
#  ({'word': 'counter-attack'}, 'positive'),
#  ({'word': 'fateful'}, 'negative'),
#  ({'word': 'bountiful'}, 'positive'),
#  ({'word': 'enrapt'}, 'positive'),
#  ({'word': 'joyfully'}, 'positive'),
#  ({'word': 'enviously'}, 'positive'),
#  ({'word': 'instrumental'}, 'positive'),
#  ({'word': 'steal'}, 'negative'),
#  ({'word': 'straightforward'}, 'positive'),
#  ({'word': 'diappointed'}, 'negative'),
#  ({'word': 'ingeniously'}, 'positive'),
#  ({'word': 'illumine'}, 'positive'),
#  ({'word': 'acrimoniously'}, 'negative'),
#  ({'word': 'downbeat'}, 'negative'),
#  ({'word': 'hoax'}, 'negative'),
#  ({'word': 'enviously'}, 'negative'),
#  ({'word': 'calumny'}, 'negative'),
#  ({'word': 'gladden'}, 'positive'),
#  ({'word': 'energy-efficient'}, 'positive'),
#  ({'word': 'insular'}, 'negative'),
#  ({'word': 'simplistic'}, 'negative'),
#  ({'word': 'wobble'}, 'negative'),
#  ({'word': 'misunderstood'}, 'negative'),
#  ({'word': 'inculcate'}, 'negative'),
#  ({'word': 'intimidation'}, 'negative'),
#  ({'word': 'holy'}, 'positive'),
#  ({'word': 'anemic'}, 'negative'),
#  ({'word': 'bastard'}, 'negative'),
#  ({'word': 'despondency'}, 'negative'),
#  ({'word': 'hum'}, 'negative'),
#  ({'word': 'delicacy'}, 'positive'),
#  ({'word': 'nauseates'}, 'negative'),
#  ({'word': 'lawless'}, 'negative'),
#  ({'word': 'error'}, 'negative'),
#  ({'word': 'luxuriate'}, 'positive'),
#  ({'word': 'preoccupy'}, 'negative'),
#  ({'word': 'glorify'}, 'positive'),
#  ({'word': 'eruption'}, 'negative'),
#  ({'word': 'unqualified'}, 'negative'),
#  ({'word': 'scorchingly'}, 'negative'),
#  ({'word': 'awestruck'}, 'positive'),
#  ({'word': 'discontinued'}, 'negative'),
#  ({'word': 'punish'}, 'negative'),
#  ({'word': 'archaic'}, 'negative'),
#  ({'word': 'delayed'}, 'negative'),
#  ({'word': 'noisier'}, 'negative'),
#  ({'word': 'momentous'}, 'positive'),
#  ({'word': 'scared'}, 'negative'),
#  ({'word': 'malaise'}, 'negative'),
#  ({'word': 'apocalypse'}, 'negative'),
#  ({'word': 'sticky'}, 'negative'),
#  ({'word': 'contribution'}, 'positive'),
#  ({'word': 'disappointment'}, 'negative'),
#  ({'word': 'discouragingly'}, 'negative'),
#  ({'word': 'prestigious'}, 'positive'),
#  ({'word': 'impractical'}, 'negative'),
#  ({'word': 'vice'}, 'negative'),
#  ({'word': 'flexibility'}, 'positive'),
#  ({'word': 'mismanage'}, 'negative'),
#  ({'word': 'thumb-down'}, 'negative'),
#  ({'word': 'abundant'}, 'positive'),
#  ({'word': 'overstate'}, 'negative'),
#  ({'word': 'reaffirmation'}, 'positive'),
#  ({'word': 'predicament'}, 'negative'),
#  ({'word': 'stubbornness'}, 'negative'),
#  ({'word': 'concede'}, 'negative'),
#  ({'word': 'unwise'}, 'negative'),
#  ({'word': 'dissention'}, 'negative'),
#  ({'word': 'eyecatch'}, 'positive'),
#  ({'word': 'rhapsodize'}, 'negative'),
#  ({'word': 'shamble'}, 'negative'),
#  ({'word': 'dread'}, 'negative'),
#  ({'word': 'immense'}, 'positive'),
#  ({'word': 'evildoer'}, 'negative'),
#  ({'word': 'grimace'}, 'negative'),
#  ({'word': 'smutty'}, 'negative'),
#  ({'word': 'exquisite'}, 'positive'),
#  ({'word': 'tetchily'}, 'negative'),
#  ({'word': 'ashamed'}, 'negative'),
#  ({'word': 'inconsiderately'}, 'negative'),
#  ({'word': 'sucker'}, 'negative'),
#  ({'word': 'favor'}, 'positive'),
#  ({'word': 'temptation'}, 'negative'),
#  ({'word': 'reprehensive'}, 'negative'),
#  ({'word': 'inefficient'}, 'negative'),
#  ({'word': 'atrophy'}, 'negative'),
#  ({'word': 'overzelous'}, 'negative'),
#  ({'word': 'excoriate'}, 'negative'),
#  ({'word': 'unwilling'}, 'negative'),
#  ({'word': 'disgustingly'}, 'negative'),
#  ({'word': 'shun'}, 'negative'),
#  ({'word': 'illusory'}, 'negative'),
#  ({'word': 'impolitely'}, 'negative'),
#  ({'word': 'bother'}, 'negative'),
#  ({'word': 'tormented'}, 'negative'),
#  ({'word': 'curse'}, 'negative'),
#  ({'word': 'stale'}, 'negative'),
#  ({'word': 'infest'}, 'negative'),
#  ({'word': 'hardship'}, 'negative'),
#  ({'word': 'adaptive'}, 'positive'),
#  ({'word': 'disadvantage'}, 'negative'),
#  ({'word': 'cool'}, 'positive'),
#  ({'word': 'exhilarating'}, 'positive'),
#  ({'word': 'toughest'}, 'positive'),
#  ({'word': 'defiance'}, 'negative'),
#  ({'word': 'tumble'}, 'negative'),
#  ({'word': 'helped'}, 'positive'),
#  ({'word': 'forbidden'}, 'negative'),
#  ({'word': 'desert'}, 'negative'),
#  ({'word': 'excruciatingly'}, 'negative'),
#  ({'word': 'sucky'}, 'negative'),
#  ({'word': 'irredeemably'}, 'negative'),
#  ({'word': 'prejudice'}, 'negative'),
#  ({'word': 'deceitful'}, 'negative'),
#  ({'word': 'inextricable'}, 'negative'),
#  ({'word': 'rot'}, 'negative'),
#  ({'word': 'fibber'}, 'negative'),
#  ({'word': 'beleaguer'}, 'negative'),
#  ({'word': 'fabulous'}, 'positive'),
#  ({'word': 'proving'}, 'positive'),
#  ({'word': 'gladness'}, 'positive'),
#  ({'word': 'jabber'}, 'negative'),
#  ({'word': 'frustration'}, 'negative'),
#  ({'word': 'unresolved'}, 'negative'),
#  ({'word': 'over-awe'}, 'negative'),
#  ({'word': 'satisfied'}, 'positive'),
#  ({'word': 'cute'}, 'positive'),
#  ({'word': 'calumny'}, 'negative'),
#  ({'word': 'ostracize'}, 'negative'),
#  ({'word': 'raptureous'}, 'positive'),
#  ({'word': 'debatable'}, 'negative'),
#  ({'word': 'stainless'}, 'positive'),
#  ({'word': 'faultless'}, 'positive'),
#  ({'word': 'farcically'}, 'negative'),
#  ({'word': 'humorous'}, 'positive'),
#  ({'word': 'diffidence'}, 'negative'),
#  ({'word': 'disrespecting'}, 'negative'),
#  ({'word': 'tumble'}, 'negative'),
#  ({'word': 'bravo'}, 'positive'),
#  ({'word': 'clumsy'}, 'negative'),
#  ({'word': 'imperious'}, 'negative'),
#  ({'word': 'overrated'}, 'negative'),
#  ({'word': 'bane'}, 'negative'),
#  ({'word': 'dead-cheap'}, 'positive'),
#  ({'word': 'oversimplified'}, 'negative'),
#  ({'word': 'blatant'}, 'negative'),
#  ({'word': 'passiveness'}, 'negative'),
#  ({'word': 'nastily'}, 'negative'),
#  ({'word': 'inconsequently'}, 'negative'),
#  ({'word': 'decadent'}, 'negative'),
#  ({'word': 'conceit'}, 'negative'),
#  ({'word': 'raptureously'}, 'positive'),
#  ({'word': 'stab'}, 'negative'),
#  ({'word': 'crap'}, 'negative'),
#  ({'word': 'rattle'}, 'negative'),
#  ({'word': 'oppressor'}, 'negative'),
#  ({'word': 'abounds'}, 'positive'),
#  ({'word': 'annoyed'}, 'negative'),
#  ({'word': 'doomed'}, 'negative'),
#  ({'word': 'disrespectfully'}, 'negative'),
#  ({'word': 'travesty'}, 'negative'),
#  ({'word': 'roomier'}, 'positive'),
#  ({'word': 'admonishingly'}, 'negative'),
#  ({'word': 'irresistible'}, 'positive'),
#  ({'word': 'warmth'}, 'positive'),
#  ({'word': 'heavenly'}, 'positive'),
#  ({'word': 'inept'}, 'negative'),
#  ({'word': 'lost'}, 'negative'),
#  ({'word': 'disappointingly'}, 'negative'),
#  ({'word': 'overheat'}, 'negative'),
#  ({'word': 'positive'}, 'positive'),
#  ({'word': 'unscrupulously'}, 'negative'),
#  ({'word': 'meticulously'}, 'positive'),
#  ({'word': 'proven'}, 'positive'),
#  ({'word': 'ruthless'}, 'negative'),
#  ({'word': 'pleasantly'}, 'positive'),
#  ({'word': 'irritation'}, 'negative'),
#  ({'word': 'limit'}, 'negative'),
#  ({'word': 'uncompetitive'}, 'negative'),
#  ({'word': 'salute'}, 'positive'),
#  ({'word': 'awed'}, 'positive'),
#  ({'word': 'inhumanity'}, 'negative'),
#  ({'word': 'worse'}, 'negative'),
#  ({'word': 'concise'}, 'positive'),
#  ({'word': 'soundly'}, 'positive'),
#  ({'word': 'clamorous'}, 'negative'),
#  ({'word': 'irritate'}, 'negative'),
#  ({'word': 'self-sufficient'}, 'positive'),
#  ({'word': 'overtakes'}, 'positive'),
#  ({'word': 'failed'}, 'negative'),
#  ({'word': 'beckoned'}, 'positive'),
#  ({'word': 'craftily'}, 'negative'),
#  ({'word': 'lure'}, 'negative'),
#  ({'word': 'imposing'}, 'negative'),
#  ({'word': 'memorable'}, 'positive'),
#  ({'word': 'generous'}, 'positive'),
#  ({'word': 'denigrate'}, 'negative'),
#  ({'word': 'lesser-known'}, 'negative'),
#  ({'word': 'rile'}, 'negative'),
#  ({'word': 'harden'}, 'negative'),
#  ({'word': 'effusion'}, 'positive'),
#  ({'word': 'god-given'}, 'positive'),
#  ({'word': 'misapprehend'}, 'negative'),
#  ({'word': 'blurring'}, 'negative'),
#  ({'word': 'inspiration'}, 'positive'),
#  ({'word': 'idiotic'}, 'negative'),
#  ({'word': 'disclaim'}, 'negative'),
#  ({'word': 'proficiently'}, 'positive'),
#  ({'word': 'sincere'}, 'positive'),
#  ({'word': 'godlike'}, 'positive'),
#  ({'word': 'recomend'}, 'positive'),
#  ({'word': 'rollercoaster'}, 'negative'),
#  ({'word': 'rocky'}, 'negative'),
#  ({'word': 'violate'}, 'negative'),
#  ({'word': 'contemptuously'}, 'negative'),
#  ({'word': 'stunned'}, 'positive'),
#  ({'word': 'enjoying'}, 'positive'),
#  ({'word': 'snagging'}, 'negative'),
#  ({'word': 'mercifully'}, 'positive'),
#  ({'word': 'belligerence'}, 'negative'),
#  ({'word': 'outsmart'}, 'positive'),
#  ({'word': 'rust'}, 'negative'),
#  ({'word': 'banish'}, 'negative'),
#  ({'word': 'utterly'}, 'negative'),
#  ({'word': 'ill-formed'}, 'negative'),
#  ({'word': 'futuristic'}, 'positive'),
#  ({'word': 'responsibly'}, 'positive'),
#  ({'word': 'hurt'}, 'negative'),
#  ({'word': 'apotheosis'}, 'positive'),
#  ({'word': 'rapturous'}, 'positive'),
#  ({'word': 'staunch'}, 'positive'),
#  ({'word': 'loophole'}, 'negative'),
#  ({'word': 'hardship'}, 'negative'),
#  ({'word': 'unconvincingly'}, 'negative'),
#  ({'word': 'incompetence'}, 'negative'),
#  ({'word': 'disliking'}, 'negative'),
#  ({'word': 'stuck'}, 'negative'),
#  ({'word': 'hard-hit'}, 'negative'),
#  ({'word': 'soulful'}, 'positive'),
#  ({'word': 'reform'}, 'positive'),
#  ({'word': 'damaged'}, 'negative'),
#  ({'word': 'relief'}, 'positive'),
#  ({'word': 'bug'}, 'negative'),
#  ({'word': 'petty'}, 'negative'),
#  ({'word': 'midget'}, 'negative'),
#  ({'word': 'skittish'}, 'negative'),
#  ({'word': 'outmoded'}, 'negative'),
#  ({'word': 'admonisher'}, 'negative'),
#  ({'word': 'infallible'}, 'positive'),
#  ({'word': 'whine'}, 'negative'),
#  ({'word': 'neglected'}, 'negative'),
#  ({'word': 'inflationary'}, 'negative'),
#  ({'word': 'avalanche'}, 'negative'),
#  ({'word': 'exagerated'}, 'negative'),
#  ({'word': 'profuse'}, 'positive'),
#  ({'word': 'din'}, 'negative'),
#  ({'word': 'unjustifiably'}, 'negative'),
#  ({'word': 'collapse'}, 'negative'),
#  ({'word': 'break'}, 'negative'),
#  ({'word': 'harangue'}, 'negative'),
#  ({'word': 'irretrievable'}, 'negative'),
#  ({'word': 'conflicting'}, 'negative'),
#  ({'word': 'nauseating'}, 'negative'),
#  ({'word': 'crafty'}, 'negative'),
#  ({'word': 'dead'}, 'negative'),
#  ({'word': 'passionate'}, 'positive'),
#  ({'word': 'profanity'}, 'negative'),
#  ({'word': 'spitefulness'}, 'negative'),
#  ({'word': 'scapegoat'}, 'negative'),
#  ({'word': 'bigotry'}, 'negative'),
#  ...]

# %%
from nltk.probability import ConditionalFreqDist, ConditionalProbDist
cfdist = ConditionalFreqDist(labeled_words)
cpdist = ConditionalProbDist(cfdist, LaplaceProbDist, bins=2)

# %%
cpdist['good'].prob('positive')
# Out:
# 0.6666666666666666

# %%
from nltk.probability import DictionaryProbDist
    
dict_probs = {'positive': .1, 'negative': .1}
label_probdist = DictionaryProbDist(dict_probs)

classifier = nltk.NaiveBayesClassifier(label_probdist=label_probdist, feature_probdist=cpdist)
classifier = classifier.train(train_data, estimator=LaplaceProbDist)

#classifier.train(train_data)                                      
#classifier.train(test_data)
print("Classifier accuracy percent: ", (nltk.classify.accuracy(classifier, test_data)*100))
# Out:
# Classifier accuracy percent:  72.38586156111928

# %%
for x in cpdist:
    print(x)
# Out:
# flareups
# lackadaisical
# vile
# wobble
# inelegant
# blind
# deceptively
# irreformable
# temptingly
# ominous
# inexperience
# insurrection
# dazzle
# entanglement
# irrelevance
# tenacity
# dizzing
# insignificance
# expeditiously
# crisis
# improvement
# upliftingly
# trustingly
# hazard
# revolutionize
# cancer
# annihilation
# clunky
# get-rich
# condescension
# skeptically
# crack
# disadvantaged
# shamefully
# threaten
# sinisterly
# celebrated
# crumpled
# plea
# confused
# chastise
# plagiarize
# irrecoverably
# crisper
# graft
# streaky
# painfull
# detrimental
# sarcastically
# clique
# tenaciously
# incoherently
# spoilage
# misery
# spurn
# nauseatingly
# dodgey
# meaningless
# uplift
# gallingly
# absurdity
# monstrosity
# unjustifiable
# blossom
# thrifty
# unreal
# nebulously
# awesomely
# recklessly
# renown
# choppy
# terror
# belittle
# jagged
# educated
# scratchy
# adverse
# immature
# unipolar
# poeticize
# vibrates
# soreness
# effusiveness
# ardently
# pep
# favorited
# seriousness
# reachable
# desolately
# erase
# dismalness
# distraughtness
# mesmerizing
# catastrophe
# disloyalty
# unruly
# unobserved
# nasty
# grateful
# boundless
# menacing
# mobster
# implausibly
# exceeds
# squash
# fault
# mortify
# struck
# illuminating
# conscons
# bullying
# revenge
# zapped
# furor
# pamper
# strife
# excuse
# tyrannically
# untimely
# sharper
# eschew
# bleakness
# rejuvenate
# askance
# wasting
# gainsayer
# suffocate
# hissing
# rockstars
# inevitable
# overwhelms
# amply
# overstatement
# deluge
# self-sufficiency
# eyecatching
# setback
# zenith
# indolent
# strongest
# unviewable
# defeated
# elatedly
# notorious
# foolhardy
# impudent
# debilitate
# maniacal
# indigent
# somber
# ruffian
# hatefulness
# disagreed
# downgrade
# relentless
# deviousness
# sensibly
# vomiting
# disreputable
# frazzle
# jerk
# buzzing
# sarcastic
# rejuvenated
# beset
# inteferes
# subsidized
# pan
# ultimatum
# shimmer
# miserably
# shameful
# pauper
# suffered
# sullen
# spiritual
# inextricably
# fruitless
# heretical
# fastest-growing
# cheer
# fright
# hestitant
# disturbingly
# elan
# reprovingly
# treason
# trickery
# selective
# glory
# elimination
# exceedingly
# negligent
# spank
# underling
# amazes
# flourishing
# freeze
# stink
# oblique
# petrified
# moribund
# loss
# imprecise
# intransigent
# delude
# monumental
# torrent
# paltry
# incompliant
# upseting
# damnation
# unrest
# bonus
# drought
# gratify
# benifits
# problem-solver
# so-cal
# crippling
# scaly
# flair
# incommensurate
# unprepared
# disastrously
# feisty
# slowed
# invalidity
# unreasonably
# autocrat
# deceiver
# wariness
# heroize
# obsolete
# sourly
# stumble
# byzantine
# beckoning
# freaking
# hedge
# refuting
# unorthodoxy
# reverently
# agony
# cuteness
# evasion
# wellbeing
# frenetically
# simplified
# contaminate
# disgusting
# despise
# obsessiveness
# smarter
# fissure
# stutter
# stifling
# abominate
# bemoan
# nervousness
# spectacularly
# contemptible
# benevolent
# beneficial
# left-leaning
# overbearingly
# crippled
# disbelieve
# involuntarily
# hard
# dependably
# curse
# ultra-crisp
# debauch
# mesmerizingly
# fainthearted
# obnoxiously
# consummate
# buggy
# sillily
# hooray
# prejudicial
# angelic
# modern
# allergic
# downer
# dilapidated
# embarrass
# indiscernible
# fatalistically
# defeat
# nonresponsive
# appreciates
# enticing
# promptly
# dissonance
# distains
# deformed
# danger
# dazzled
# infirm
# recklessness
# satirical
# dismal
# niggles
# chatter
# oversight
# irresistibly
# tenacious
# inequity
# implicate
# fast-paced
# comical
# altruistically
# nightmarish
# unnerved
# bankrupt
# prestige
# underpaid
# distrusting
# disillusioned
# mightily
# tank
# mispronounces
# monumentally
# craze
# raked
# frustration
# excites
# unwelcome
# conflict
# bleeding
# gratifyingly
# senile
# reaffirm
# assurance
# traumatized
# unexplained
# absurdness
# fabricate
# oddity
# intolerablely
# magnificent
# brainy
# hostility
# cruelest
# sick
# cripple
# repressive
# bulkyness
# lapse
# wise
# ineffectual
# attentive
# felonious
# slumpping
# nicer
# saving
# taut
# handier
# corrosive
# infidel
# thrive
# maneuverable
# sermonize
# youthful
# oversize
# discourteous
# pander
# vibrated
# punch
# aggrieved
# irrepressible
# hegemonism
# cuplrit
# appreciated
# incautious
# loathly
# bumped
# unfit
# adventurous
# ample
# distraughtly
# feverish
# fall
# rumple
# harmed
# falter
# impetuously
# tin-y
# displeasing
# non-violent
# razor-sharp
# fathomless
# depravedly
# haywire
# superstition
# inspire
# exterminate
# regret
# offender
# pre-eminent
# randomly
# glamorous
# elegantly
# pretentiously
# deceptive
# encouragement
# rumor
# desiccated
# immaculate
# injurious
# ignoble
# terrible
# considerate
# bowdlerize
# ineloquently
# rewarding
# laid-off
# wrip
# enchanting
# bleeds
# vengefully
# unreliable
# advantage
# perplex
# smudging
# astutely
# exceeded
# incompetent
# protest
# cheaply
# retardedness
# fractiously
# disapprove
# civility
# cheapest
# pillory
# mischievously
# loneliness
# hassle
# declaim
# lyrical
# acridness
# smilingly
# knotted
# laudably
# friction
# desititute
# screw-up
# dreadfully
# brainwash
# skillful
# unhappy
# ebullience
# villainous
# blindside
# prosperity
# indulgent
# fascination
# appallingly
# animosity
# embroiled
# peculiarly
# trauma
# smelly
# heretic
# recalcitrant
# precariously
# trusting
# logical
# wonderous
# protracted
# dubiously
# overwhelm
# despotic
# retractable
# objection
# drawback
# ripoff
# pig
# furious
# horrendous
# thumbs-down
# fraught
# aborted
# jolly
# striking
# ingrate
# shroud
# outdo
# shadowy
# lackey
# graciousness
# detracted
# radicalization
# entrap
# upgradeable
# revengefully
# wripped
# unfavorable
# marginal
# full-blown
# damned
# illuminati
# interrupt
# inhuman
# handsomely
# cheerful
# scrap
# forswear
# effortless
# affordably
# crumbling
# handily
# irate
# slump
# convient
# dissing
# hard-line
# smouldering
# unimportant
# infringement
# fame
# grouse
# impoverished
# amity
# hypocrite
# mindlessly
# quarrelsome
# dust
# ill-used
# ill-designed
# suitable
# available
# enviable
# confuse
# whoa
# weariness
# restriction
# tantalize
# deference
# equivocal
# criticize
# exemplary
# repulsively
# enticed
# famished
# enmity
# ill-conceived
# nice
# unwatchable
# mocked
# affectation
# serene
# depression
# pestilent
# annoyance
# ill-favored
# bias
# panicking
# strangest
# zeal
# back-woods
# stylishly
# patient
# gallantly
# disgraced
# freshest
# alienation
# lividly
# phobic
# inconsequential
# erudite
# pugnacity
# famine
# imaginary
# squabble
# joyous
# prudent
# lethargy
# imbalance
# disquieting
# opinionated
# unreachable
# coupists
# propagandize
# dexterous
# cuss
# overwhelmingly
# perturb
# denying
# pertinaciously
# puzzling
# aspersion
# hissed
# haggle
# unaccessible
# inestimably
# humane
# derisively
# wasteful
# unlamentable
# unbearablely
# illusion
# moron
# stain
# remission
# ameliorate
# chaos
# hothouse
# headache
# uproarously
# fleed
# unsure
# intolerable
# expunge
# wrongful
# insightfully
# bump
# gainsay
# calamitous
# disgracefully
# trump
# revolutionary
# brute
# marvellous
# shamelessly
# dissenter
# hairloss
# heroically
# relapse
# predatory
# stump
# nettlesome
# wealthy
# breakdown
# finest
# violently
# precious
# mesmerize
# virtue
# inhospitality
# sloppy
# swiftness
# blithe
# feeble
# beneficiary
# infected
# boredom
# uneventful
# faithful
# hectic
# grotesque
# corruption
# disorder
# dissonantly
# detracting
# insidious
# trivialize
# traumatically
# rightful
# speedy
# licentious
# unkindly
# rockstar
# disgustful
# imprudence
# implication
# slaughter
# distract
# substantive
# influential
# continuity
# warp
# ridicule
# high-quality
# thoughtfully
# affliction
# concerned
# totalitarian
# irreproachable
# accursed
# enflame
# stupendously
# imbroglio
# inequality
# admirable
# elevate
# chunky
# assuredly
# surpass
# providence
# displeasure
# stumbled
# motley
# throbbed
# gruesomely
# unreasonable
# haphazard
# irony
# keenness
# snare
# strikingly
# exaggeration
# recommended
# upset
# exceptionally
# insinuate
# phenomenally
# fond
# inconsiderate
# lively
# misfortune
# 2-faces
# malcontented
# repugnance
# deny
# timid
# slut
# streamlined
# jeeringly
# fleeting
# disarray
# jealousy
# heckle
# counter-attack
# fateful
# bountiful
# enrapt
# joyfully
# enviously
# instrumental
# steal
# straightforward
# diappointed
# ingeniously
# illumine
# acrimoniously
# downbeat
# hoax
# calumny
# gladden
# energy-efficient
# insular
# simplistic
# misunderstood
# inculcate
# intimidation
# holy
# anemic
# bastard
# despondency
# hum
# delicacy
# nauseates
# lawless
# error
# luxuriate
# preoccupy
# glorify
# eruption
# unqualified
# scorchingly
# awestruck
# discontinued
# punish
# archaic
# delayed
# noisier
# momentous
# scared
# malaise
# apocalypse
# sticky
# contribution
# disappointment
# discouragingly
# prestigious
# impractical
# vice
# flexibility
# mismanage
# thumb-down
# abundant
# overstate
# reaffirmation
# predicament
# stubbornness
# concede
# unwise
# dissention
# eyecatch
# rhapsodize
# shamble
# dread
# immense
# evildoer
# grimace
# smutty
# exquisite
# tetchily
# ashamed
# inconsiderately
# sucker
# favor
# temptation
# reprehensive
# inefficient
# atrophy
# overzelous
# excoriate
# unwilling
# disgustingly
# shun
# illusory
# impolitely
# bother
# tormented
# stale
# infest
# hardship
# adaptive
# disadvantage
# cool
# exhilarating
# toughest
# defiance
# tumble
# helped
# forbidden
# desert
# excruciatingly
# sucky
# irredeemably
# prejudice
# deceitful
# inextricable
# rot
# fibber
# beleaguer
# fabulous
# proving
# gladness
# jabber
# unresolved
# over-awe
# satisfied
# cute
# ostracize
# raptureous
# debatable
# stainless
# faultless
# farcically
# humorous
# diffidence
# disrespecting
# bravo
# clumsy
# imperious
# overrated
# bane
# dead-cheap
# oversimplified
# blatant
# passiveness
# nastily
# inconsequently
# decadent
# conceit
# raptureously
# stab
# crap
# rattle
# oppressor
# abounds
# annoyed
# doomed
# disrespectfully
# travesty
# roomier
# admonishingly
# irresistible
# warmth
# heavenly
# inept
# lost
# disappointingly
# overheat
# positive
# unscrupulously
# meticulously
# proven
# ruthless
# pleasantly
# irritation
# limit
# uncompetitive
# salute
# awed
# inhumanity
# worse
# concise
# soundly
# clamorous
# irritate
# self-sufficient
# overtakes
# failed
# beckoned
# craftily
# lure
# imposing
# memorable
# generous
# denigrate
# lesser-known
# rile
# harden
# effusion
# god-given
# misapprehend
# blurring
# inspiration
# idiotic
# disclaim
# proficiently
# sincere
# godlike
# recomend
# rollercoaster
# rocky
# violate
# contemptuously
# stunned
# enjoying
# snagging
# mercifully
# belligerence
# outsmart
# rust
# banish
# utterly
# ill-formed
# futuristic
# responsibly
# hurt
# apotheosis
# rapturous
# staunch
# loophole
# unconvincingly
# incompetence
# disliking
# stuck
# hard-hit
# soulful
# reform
# damaged
# relief
# bug
# petty
# midget
# skittish
# outmoded
# admonisher
# infallible
# whine
# neglected
# inflationary
# avalanche
# exagerated
# profuse
# din
# unjustifiably
# collapse
# break
# harangue
# irretrievable
# conflicting
# nauseating
# crafty
# dead
# passionate
# profanity
# spitefulness
# scapegoat
# bigotry
# despairing
# panicked
# moronic
# dehumanize
# tenderly
# cronyism
# impassioned
# adulterier
# disregardful
# recommendation
# sore
# flicering
# over-balanced
# shameless
# woo
# tricky
# dis
# backward
# racy
# whiny
# guiltless
# cooperatively
# large-capacity
# affluence
# worthlessness
# cunt
# agilely
# gimmicking
# mediocrity
# award
# overbalanced
# poetic
# subpoena
# difficulty
# chastisement
# harmoniously
# darker
# omission
# portable
# eagerness
# dissappointing
# exorbitantance
# objectionable
# enlighten
# ridiculously
# rut
# mourn
# shortness
# bluring
# noble
# undermining
# liable
# torment
# insociable
# bullshit
# erodes
# rectification
# offensively
# courageously
# shark
# misjudge
# doomsday
# misbecoming
# satirize
# masterfully
# pitiless
# tangled
# recoil
# cocky
# unreadable
# vague
# soothe
# thrill
# mangle
# impatient
# complex
# examplar
# formidable
# impair
# repulsed
# humorously
# irksomely
# complains
# mire
# gullible
# messing
# finely
# discompose
# overshadow
# whooa
# concern
# careless
# sufficed
# woebegone
# deviation
# ecstatically
# b
# jobless
# helpful
# extol
# dull
# unrealistic
# impending
# decayed
# unworthy
# dilemma
# tingled
# interference
# outperforms
# swankier
# jeer
# lawbreaking
# undone
# forebodingly
# spotty
# incompatability
# wholesome
# effectiveness
# flaunt
# dissuasive
# discordant
# disgrace
# mockingly
# dedicated
# disruptive
# benefactor
# truthfulness
# asperse
# lustrous
# turmoil
# overblown
# gimmicky
# smugly
# tricked
# ramshackle
# persecution
# resentful
# picket
# detracts
# enrich
# healthful
# bashed
# meritorious
# trample
# enhanced
# hands-down
# irreversible
# slack
# peculiar
# classy
# disallow
# ludicrous
# litigious
# sugar-coated
# spellbindingly
# lavishly
# angry
# restructured
# inexpertly
# languorous
# unscrupulous
# sufficient
# ecenomical
# expired
# manipulator
# kill
# opposition
# devil
# unclean
# unrestricted
# manipulate
# reasonable
# deplore
# onslaught
# creak
# petrify
# positively
# heartening
# tedious
# pleasurable
# wow
# pernicious
# dexterously
# sue
# luxurious
# deft
# supreme
# gainful
# divisiveness
# dissatisfied
# devastating
# infiltrator
# isolated
# record-setting
# jerky
# disturbing
# low-risk
# castrated
# clog
# amusingly
# annoy
# tranquility
# farfetched
# outperformed
# brightest
# banal
# languorously
# avaricious
# invalidate
# licentiously
# heal
# nicely
# danke
# stigma
# fascist
# startlingly
# audacious
# invidiousness
# severity
# vociferous
# layoff
# vagueness
# miscreant
# spotless
# charming
# mundane
# ruthlessly
# gainfully
# usurp
# wilt
# loot
# politeness
# repetitive
# vexing
# dignified
# lovable
# significant
# tramp
# faithfully
# concen
# villain
# insufficient
# prodigiously
# outperforming
# dreamland
# magic
# sagely
# brighter
# flake
# ache
# trouble
# survivor
# livid
# ruin
# felicity
# inconsistent
# tragic
# irksome
# superb
# solicitously
# satisfying
# arrogantly
# pleasurably
# overemphasize
# selfish
# softer
# mercy
# subdued
# pandering
# lethal
# scant
# condescendingly
# ignominious
# overjoyed
# crumple
# maturely
# lean
# degrading
# villianously
# compactly
# butchery
# sneeringly
# mope
# exalted
# chintzy
# mangled
# overplay
# compassionate
# vigilance
# steeply
# derisiveness
# cushy
# melodramatically
# abundance
# boom
# defy
# doubtful
# catastrophically
# timidness
# paramount
# inefficacious
# perplexity
# over-priced
# bothersome
# celebratory
# kooky
# capsize
# thrillingly
# dissappointed
# slothful
# disaffect
# refund
# defrauding
# radiant
# effectively
# discredit
# whimper
# compliant
# effusive
# poky
# dirt-cheap
# upbeat
# conspiracy
# ambitiously
# con
# plague
# deride
# repudiation
# unproductive
# succeeds
# prudently
# tender
# ill-advised
# succeeded
# spoon-fed
# maliciousness
# gimmick
# bull----
# non-violence
# clear
# illegitimate
# impulsively
# absent-minded
# fancier
# resourcefulness
# regretful
# rancor
# trash
# top-heavy
# entertain
# heroine
# slave
# egocentric
# luxuriant
# sincerity
# entrapment
# recession
# enrage
# hysteric
# hesitant
# clever
# fave
# replaceable
# complaining
# break-up
# avidly
# inundate
# flicker
# achievible
# eagerly
# subjugate
# pretend
# fatuously
# mishandle
# capriciously
# raping
# asunder
# afflict
# astoundingly
# cursed
# treachery
# insubordinate
# immoderately
# scratch
# undisputably
# superficially
# obscures
# merit
# empathy
# gracefully
# virtuous
# courageous
# irrational
# gaffe
# betray
# cravenly
# instability
# ineffective
# perverse
# agonize
# militancy
# defect
# irresponsible
# suicide
# delightful
# despicable
# bruised
# bereave
# substandard
# everlasting
# burned
# err
# despair
# well-rounded
# raped
# prevaricate
# sufferer
# multi-polarization
# joy
# bulky
# prettily
# restful
# panoramic
# polished
# exhaustion
# conciliatory
# wonderful
# destains
# quash
# toughness
# illustrious
# honored
# glitter
# feckless
# pitilessly
# congenial
# nourishing
# hothead
# outlaw
# dy
# rubbish
# set-up
# syndrome
# stereotypically
# oasis
# jaded
# inhibit
# thrilled
# hurtful
# insidiously
# pricier
# staunchly
# captivating
# nemesis
# unaffected
# disrespectfulness
# broken-hearted
# bull****
# fulminate
# dragged
# subsidize
# massacre
# industrious
# reasoned
# dislike
# fallacy
# blockhead
# thank
# appeal
# cautionary
# sack
# bonny
# hang
# delay
# screwed-up
# clamor
# unusual
# swagger
# admirer
# blurred
# shimmering
# smooth
# shrill
# retarded
# unfounded
# brutality
# stooge
# invisible
# extravagance
# integral
# restless
# genius
# slander
# visionary
# a+
# frenzy
# impolitic
# unbound
# inviolable
# imperfectly
# mastery
# scramble
# perfection
# useable
# cramping
# inoperable
# purify
# reprehensibly
# poverty
# evil
# hawkish
# impolite
# spews
# lukewarm
# hating
# unhealthy
# monotonous
# accomplished
# excited
# joyful
# goad
# avarice
# trophy
# worn
# subjection
# gall
# sharp
# fiery
# skimpy
# inaccurate
# frown
# stupify
# qualify
# doddering
# energetic
# excessively
# obscene
# beckons
# unexpectedly
# counter-attacks
# deceitfully
# scream
# risk
# rightfully
# insinuating
# invidious
# harassment
# generosity
# inspiring
# scarily
# unneeded
# hedonistic
# important
# outstanding
# grand
# dismissively
# inflame
# engaging
# cringe
# crowdedness
# wearisome
# died
# disquietude
# abusive
# easiness
# cracked
# anti-us
# fume
# sane
# liberty
# rejoicingly
# disinclination
# exorbitantly
# brutally
# problem-free
# brittle
# asinine
# indecisively
# accusation
# advocated
# uninsured
# gape
# retreat
# virulently
# incoherent
# steadfast
# passionately
# justly
# bungling
# betrayal
# indiscretion
# unpleasant
# unstable
# preferably
# meticulous
# disvalue
# 2-faced
# obsessively
# leaking
# cramped
# regressive
# firmer
# idyllic
# derision
# weaker
# goodness
# drop-out
# constructive
# dissolute
# stumped
# gripe
# deficiency
# laughably
# stressful
# gnawing
# blemish
# reconcile
# personage
# felon
# gutsy
# commonplace
# subordinate
# weaken
# mistaken
# problem
# splendidly
# dissolution
# troublingly
# anxiously
# hostile
# vindictive
# inexpensive
# two-faced
# naively
# spellbinding
# impossible
# stimulative
# valuable
# detraction
# appal
# desperate
# hallucination
# officious
# bondage
# noise
# downturn
# hassled
# adored
# subjugation
# blaspheme
# batty
# adequate
# agility
# tout
# mistrustful
# flirty
# grossly
# sully
# wonderfully
# grudgingly
# crowded
# blow
# credulous
# hostage
# toll
# limp
# adaptable
# strictly
# openness
# profoundly
# sweetness
# disconsolately
# scar
# amicably
# fatal
# shady
# unbelievably
# renaissance
# obtuse
# irritable
# well-run
# cleverly
# rejecting
# fatcats
# mordantly
# jubilant
# despondence
# morality
# geekier
# panic
# spitefully
# meanness
# endorses
# compatible
# restricted
# fastest
# topple
# cheerless
# shortchange
# workable
# anti-
# articulate
# disown
# unreliability
# picketed
# misinformed
# despoil
# distaste
# aggressiveness
# worrier
# ecstasy
# unaccustomed
# discontinuous
# authentic
# prohibit
# overtaken
# unlawfulness
# revitalize
# contradict
# romantic
# unsettling
# bemused
# wickedly
# sour
# expire
# tetchy
# dubitable
# intimate
# blabber
# vouch
# egregious
# immaculately
# horrible
# retract
# rosy
# fastidiously
# unorthodox
# enviousness
# imperfection
# miserly
# wowed
# nonsense
# convenient
# sporadic
# impressively
# irately
# malevolently
# trap
# civilize
# inequitably
# creative
# intrude
# hatred
# disgruntled
# sabotage
# stalemate
# poor
# venomously
# self-interest
# low-rated
# drippy
# heck
# suffers
# compulsion
# hapless
# dismay
# abuse
# ridiculous
# willingness
# idiot
# impeccable
# indelicate
# hoodwink
# poison
# raging
# cash-strapped
# revoltingly
# extort
# venomous
# work
# deplorable
# unquestionable
# infraction
# excitement
# rejected
# discrimination
# peeled
# busybody
# insensitively
# advanced
# complicit
# cruel
# pique
# scam
# hotcake
# impatiently
# modesty
# forlorn
# beastly
# backwardness
# gangster
# marvelous
# scarce
# hero
# heathen
# scum
# indifference
# immoral
# gladly
# gibe
# nauseate
# blunder
# lawlessness
# thoughtful
# sloww
# favorable
# vibrantly
# low-priced
# egotistical
# disliked
# destitution
# well-balanced
# impartial
# rival
# abscond
# pale
# revolutionizes
# disregard
# butcher
# infection
# imprecisely
# haze
# accurately
# condemns
# sturdy
# cumbersome
# unresponsive
# savaged
# screwed
# hack
# brilliantly
# begging
# musty
# unnecessary
# adulatory
# ignominiously
# inadequately
# revives
# dupe
# profusion
# excellent
# irregularity
# sinister
# impotent
# loyalty
# draconic
# strenuous
# immodest
# moan
# hypocrisy
# overthrow
# rash
# malignant
# stringent
# back-wood
# comfort
# saggy
# astonishment
# contravene
# chivalrous
# outburst
# win
# irrecoverableness
# polluter
# bicker
# fanaticism
# indeterminate
# grieve
# suicidal
# assassinate
# nourish
# trashy
# smuttier
# overreach
# complain
# crisp
# exceptional
# gibber
# envious
# hilarious
# homage
# fool
# compassion
# inconstant
# sadness
# twist
# complacent
# undisputed
# accidental
# outstandingly
# insolently
# burdensome
# dissed
# pain-free
# shortcoming
# devilish
# neurotic
# averse
# fortunate
# supported
# stupid
# disobey
# confusion
# pleasant
# stimulates
# brighten
# sophisticated
# dignity
# frigid
# humble
# sober
# incivility
# blur
# pout
# endear
# meddle
# irresolvable
# degenerate
# mislead
# stressfully
# acerbate
# bewilderment
# pathetic
# struggle
# fairness
# rebuke
# worst
# self-destructive
# successful
# adroitly
# grumpily
# gusto
# ignorant
# smartly
# fooled
# hideousness
# punctual
# incite
# implacable
# durable
# outperform
# elite
# leery
# disconcert
# dismissive
# exceeding
# miracle
# safely
# regression
# eulogize
# back-logged
# heroic
# teasingly
# low-cost
# perfectly
# calming
# tiresome
# antithetical
# uneasily
# decisive
# expertly
# gaff
# assail
# uncivil
# spew
# dirt
# stimulating
# paradoxical
# complement
# merriness
# enthusiastically
# collude
# wonder
# luckiest
# gasp
# sedentary
# anxiety
# fracture
# culpable
# bid-rigging
# paranoia
# irresolute
# empowerment
# misguide
# brazen
# sidetracked
# slogs
# ardor
# oddly
# obstructed
# fairly
# untrue
# disapointing
# devilry
# celebrate
# condemnation
# polution
# swollen
# appreciative
# inimically
# conscientious
# culprit
# bleakly
# inclement
# breach
# acumen
# broke
# inestimable
# disoriented
# radical
# affable
# incoherence
# insouciance
# shrivel
# futile
# flatter
# fret
# gloriously
# disdained
# infuriating
# dishonorablely
# multi-purpose
# afordable
# strangle
# craven
# champ
# stronger
# attack
# flagrantly
# stark
# exhaust
# pittance
# sublime
# energize
# ragged
# excitingly
# aver
# amazed
# unacceptablely
# keenly
# elate
# brash
# skeptical
# prospros
# dismaying
# acclaimed
# dangerousness
# exagerates
# obscenely
# honest
# weakness
# fatuous
# thoughtless
# flirt
# cheapen
# agreeableness
# anti-white
# smoothes
# swipe
# punitive
# desperately
# ill-fated
# aggression
# unacceptably
# banalize
# carefree
# selfinterested
# queer
# rapt
# allegation
# degrade
# diatribe
# evaluative
# eminence
# glare
# glimmering
# flare
# grumpier
# overlook
# glee
# dimmer
# antipathy
# execrate
# resignation
# nimble
# abound
# warning
# unparalleled
# top
# luckiness
# ebullient
# preposterous
# robust
# dreadfulness
# matchless
# effortlessly
# invigorate
# gaudy
# discontentedly
# hopeless
# lovelorn
# afford
# quibble
# confession
# maddening
# fever
# mighty
# bloated
# inapt
# obscenity
# cozy
# kook
# undetermined
# flimsy
# tangle
# deaf
# lurking
# fist
# relentlessness
# brazenness
# gawky
# uninformed
# cliche
# mistress
# sorrowful
# mistified
# admire
# ploy
# uproar
# unfaithful
# ovation
# revoke
# destruction
# glib
# despot
# grandeur
# comfortably
# disfavor
# promising
# flimflam
# unspeakable
# downhearted
# disgustfully
# exclusion
# puppet
# enjoyable
# prodigious
# defamation
# misunderstanding
# dripping
# reforming
# confound
# defiantly
# corrosion
# disapproving
# defame
# sob
# drip
# usurper
# unhelpful
# stormy
# ailing
# deadbeat
# ire
# proactive
# frustrating
# recessionary
# forgetfulness
# conveniently
# affably
# ultra-hardline
# trouble-free
# thankful
# broken
# miff
# death
# fumble
# bravado
# skulk
# earsplitting
# harm
# offense
# outwit
# enjoyably
# gritty
# devilishly
# slammin
# illogically
# cloud
# hallmark
# conspicuously
# opportunistic
# godsend
# overdo
# dastardly
# suffice
# inconsequentially
# cherished
# swamped
# precarious
# secure
# hotbed
# chronic
# scenic
# breathtakingly
# blunt
# admiration
# decrepitude
# assure
# cherub
# paranoid
# invader
# acclamation
# uproarious
# dripped
# entrust
# love
# unfinished
# tragically
# complaint
# excel
# beggarly
# thug
# recover
# disconsolate
# mock
# frolic
# contentious
# haste
# lovably
# protect
# disintegration
# hot
# denunciation
# cave
# absentee
# delusion
# rampage
# warmhearted
# resigned
# growl
# merciful
# clearly
# undocumented
# denounce
# drain
# indignantly
# reclaim
# corrupted
# tremendously
# scornful
# cooperative
# arduous
# breakup
# law-abiding
# truthful
# contaminates
# less-developed
# promised
# dent
# dinky
# grumble
# hurting
# smell
# greed
# disconcerting
# hypocritical
# provocative
# divinely
# darken
# contrived
# malign
# traitorous
# insurmountable
# devout
# grumpiest
# impinge
# warped
# mishap
# harasses
# temper
# lewdly
# jam
# boastful
# marvelously
# abnormal
# exemplar
# superstitious
# quieter
# exquisitely
# luster
# truthfully
# cohere
# curt
# vanity
# well-positioned
# apprehensively
# heinous
# unsupported
# inhibition
# drab
# shamefulness
# reputation
# smoothest
# capriciousness
# warlike
# mystery
# scoundrel
# untrustworthy
# sustainability
# cataclysmically
# delirium
# cranky
# unwieldy
# refusing
# lie
# bashing
# sorely
# better
# traumatize
# tarnish
# disintegrate
# parody
# flutter
# productive
# exaltedly
# desirable
# warily
# instructive
# insane
# sap
# ungrateful
# abrupt
# hypocritically
# thrilling
# unforgettable
# crime
# die-hard
# symptom
# ranted
# denunciate
# pessimistically
# zippy
# foresight
# detest
# abrade
# turbulent
# ineffectually
# leak
# farcical-yet-provocative
# tauntingly
# improbably
# fascinating
# joyously
# unpleasantries
# abomination
# vainly
# anarchy
# undamaged
# wieldy
# pamperedness
# led
# mercilessly
# lying
# poise
# sugarcoated
# disruption
# ecstatic
# squander
# frugal
# spellbind
# excitedness
# mess
# stylized
# covetous
# disapproval
# crazy
# stampede
# easing
# injudicious
# hale
# riled
# deploringly
# inflated
# instigator
# derisive
# stiflingly
# disillusion
# adamantly
# well
# ill-mannered
# extraordinary
# unsettlingly
# promoter
# dangerous
# besmirch
# manic
# immovable
# smolder
# cure-all
# dreary
# intolerance
# persecute
# darling
# misleading
# invigorating
# irrationally
# better-than-expected
# fidelity
# inaptitude
# snob
# jeopardy
# notoriety
# poised
# funny
# indebted
# sufficiently
# coolest
# enraptured
# unquestionably
# starve
# resilient
# disasterous
# tediously
# desolation
# encouragingly
# mysteriously
# devious
# complemented
# lead
# cackle
# battered
# madder
# bless
# altercation
# exacerbate
# foulness
# frantically
# peppy
# rantingly
# ingenuity
# cheaper
# impeach
# appalled
# distinction
# hatefully
# killing
# bombard
# inaction
# fidget
# eye-catch
# best-known
# graciously
# neatly
# haunting
# unuseably
# clarity
# miraculousness
# powerful
# eviscerate
# hell
# bewilderingly
# joke
# dictator
# undermine
# reject
# assault
# peeved
# ilu
# credible
# miraculously
# fascinatingly
# chaff
# creep
# jubilantly
# loner
# overtaxed
# indiscriminating
# sensationally
# perversely
# undermines
# flareup
# superbly
# adorer
# bum
# passive
# mawkishly
# indoctrinate
# fondness
# imprudent
# bloodshed
# volatile
# enhancement
# concession
# disagreeable
# gloomy
# refuse
# anxious
# emasculate
# molestation
# resistance
# avariciously
# friggin
# unconditional
# debt
# wowing
# obstructs
# genocide
# vivid
# spewed
# carnage
# flaw
# unsuccessfully
# outrageously
# nobly
# fear
# starvation
# remorselessly
# false
# rotten
# commiserate
# rhetorical
# ambiguous
# brilliance
# enraged
# revere
# vibrate
# encourage
# costly
# poisonously
# odor
# insanely
# meager
# wasted
# helplessness
# wrest
# beauty
# shimmeringly
# sorry
# inexpert
# trusty
# bellicose
# heedless
# exonerate
# dizzingly
# tenuous
# disbelief
# mockery
# reticent
# perseverance
# upheaval
# aground
# temerity
# faze
# rapture
# disinterested
# glad
# hazy
# worked
# loyal
# interest
# worthlessly
# barbarically
# conciliate
# disappoints
# sucked
# loathsome
# complained
# rankle
# condemnable
# demise
# imprecate
# gross
# disconsolation
# breakthrough
# superiority
# blissfully
# desirous
# frightfully
# well-behaved
# invalid
# useless
# pricey
# dubious
# defunct
# super
# inanely
# frightening
# uneasy
# incomparably
# sloow
# inability
# spoiled
# longing
# commitment
# ideally
# suffer
# affability
# showdown
# throb
# confined
# bleed
# sluggish
# enraging
# courageousness
# regretted
# miscalculation
# success
# bitter
# blurry
# inferior
# nosey
# dejectedly
# humour
# elegance
# obscure
# fervent
# sinful
# coherent
# embarrassment
# forgetful
# chilly
# injustice
# destroyer
# hung
# rue
# gruesome
# undermined
# timidity
# expropriation
# crash
# meltdown
# ill-treatment
# fun
# anarchism
# obstinate
# lecherous
# drastic
# freezing
# adore
# graceless
# defensive
# mistake
# cowardly
# unjust
# limitation
# failure
# liability
# unclear
# dilly-dally
# indifferent
# amenity
# thumb-up
# indeterminably
# destabilisation
# fugitive
# freak
# smudge
# disintegrates
# impasse
# childish
# harboring
# inevitably
# cheat
# popular
# leakage
# cost-saving
# inopportune
# gossip
# oversimplification
# malice
# pretence
# triumphal
# goodly
# uneasiness
# inhumane
# antiquated
# vain
# mulish
# rewardingly
# rabid
# fail
# shake
# unwell
# anti-proliferation
# gratefully
# blockbuster
# dehumanization
# impoverish
# outshone
# speedily
# partisan
# ailment
# loose
# subtract
# timidly
# harassed
# guilty
# snazzy
# wisely
# dispute
# gleeful
# intelligible
# desultory
# combust
# modest
# despondently
# refuted
# catchy
# handsome
# heckled
# stunted
# outshine
# subjected
# disunity
# brainless
# anarchist
# triumphant
# brutal
# sweeten
# complementary
# discriminate
# affordable
# fanciful
# proficient
# drag
# gratifies
# romantically
# tainted
# faith
# irked
# attractive
# clash
# offending
# viper
# clearer
# anxiousness
# liking
# gleefully
# quarrel
# lemon
# trumpet
# relent
# scarcely
# fudge
# enchant
# dumping
# implausible
# loser
# crashing
# inefficiently
# sickly
# smoothly
# intimidate
# honesty
# overpriced
# sceptical
# refreshed
# calm
# drained
# hopeful
# prominence
# doldrums
# annoyingly
# spacious
# enervate
# disgusted
# threesome
# unsuccessful
# smelled
# scandalous
# hug
# unpredictable
# dawn
# crush
# unpopular
# convienient
# inescapable
# excitedly
# tumbled
# god-awful
# skill
# fast
# distort
# unsophisticated
# panick
# hysterically
# lagged
# retaliate
# extremist
# displace
# solicitude
# outcry
# groundbreaking
# undisputable
# tardy
# fallaciously
# bewitch
# solidarity
# impropriety
# brutish
# demoralize
# proper
# expel
# hater
# contempt
# unassailable
# brashness
# dominated
# proprietary
# nervously
# negative
# squirm
# detests
# flounder
# saintliness
# sexy
# perish
# inspirational
# forbid
# sickening
# fascism
# harrow
# paradoxically
# luck
# corrupts
# state-of-the-art
# affront
# detract
# tenuously
# downside
# insanity
# torture
# brotherly
# faulty
# spirited
# misjudgment
# creeping
# punishable
# painless
# dwindling
# enemy
# hooligan
# jealously
# combative
# fortune
# swindle
# madden
# brilliant
# backaching
# terrorism
# second-tier
# sweet
# squeal
# magnificence
# war-like
# mortified
# euphoric
# meaningful
# diversified
# danken
# impress
# tattered
# prosperous
# ambiguity
# downhill
# freakishly
# enlightenment
# indiscreet
# annihilate
# bitterly
# insulting
# fearlessly
# disapprobation
# cruelness
# guiltily
# untested
# slaughtered
# bully
# resolute
# washed-out
# belittling
# disastrous
# lover
# courteous
# scowl
# upgraded
# cleared
# kindliness
# lechery
# surrender
# dreadful
# revival
# ill-natured
# twisted
# fragile
# prof
# laughable
# like
# unaffordable
# apocalyptic
# squeak
# intense
# unsettle
# attune
# smug
# faint
# miser
# cheap
# peril
# drunkard
# hegemonistic
# unsustainable
# wrinkle
# die
# zap
# grisly
# anti-semite
# lucky
# expansive
# insupportably
# grating
# disdainful
# backbite
# insensible
# satisfies
# hardheaded
# strange
# dusty
# greatest
# prize
# heartbreakingly
# lumpy
# intefere
# shit
# dazzling
# shock
# disapointment
# unrelenting
# patriot
# incomplete
# seamless
# jaw-dropping
# violator
# vent
# soundness
# gabble
# infested
# unfamiliar
# stiff
# eased
# thoughtfulness
# stupified
# hideous
# excellant
# revolutionized
# lone
# discomfititure
# preposterously
# garbage
# crumble
# well-being
# issue
# mangling
# wretchedly
# galling
# vociferously
# anti-occupation
# burdensomely
# weirdly
# bickering
# readily
# standout
# jitter
# disaffected
# doom
# squeaky
# malevolent
# irregular
# futilely
# sumptuous
# falling
# heartwarming
# excellency
# cashbacks
# incompatible
# acerbically
# direness
# stodgy
# baffled
# bungler
# stench
# advocate
# belligerent
# peevish
# scrambling
# ineptly
# nifty
# clogged
# tingle
# horrific
# disdain
# smelling
# dauntless
# acrimonious
# efficient
# inviolate
# figurehead
# ill-defined
# distressing
# righteously
# consistently
# static
# illegal
# goofy
# puzzlement
# excelled
# insecure
# boggle
# farcical
# plot
# uncompromising
# carelessness
# repel
# shrug
# unbeatable
# sensationalize
# distrustful
# uproariously
# first-rate
# murderer
# adulteration
# user-friendly
# prate
# froze
# slow-moving
# regress
# diabolic
# inadequacy
# wretched
# moody
# titillatingly
# despoiler
# irk
# lanky
# dishonest
# dummy-proof
# smart
# fatigue
# idealize
# fanatic
# slashing
# rapid
# unconfirmed
# incessant
# indignant
# stolen
# irritated
# incongruous
# adulterate
# dark
# calmness
# scandal
# demonizing
# beware
# self-criticism
# uprising
# fashionably
# irking
# offence
# primitive
# marvel
# intricate
# posturing
# progressive
# fragmented
# weak
# vomit
# woe
# indignity
# dextrous
# slower
# astray
# overturn
# confrontational
# complicated
# reliable
# fat
# tension
# sloppily
# bewildering
# stereotype
# privilege
# commodious
# appropriate
# conceded
# revulsion
# luxury
# sag
# shabby
# crook
# vengeance
# eccentricity
# tease
# allergy
# detestable
# disappointed
# election-rigger
# delinquency
# bust
# renounce
# dissatisfaction
# unequivocal
# inexcusably
# disservice
# happy
# sneer
# vulnerable
# jumpy
# frantic
# cataclysm
# fatcat
# naĂŻve
# indecent
# prejudge
# rejoice
# vengeful
# plus
# ethical
# capable
# disobedience
# bitterness
# spoil
# fortunately
# idol
# unnerve
# plaything
# fine-looking
# pain
# dastard
# hospitable
# conspiratorial
# dispensable
# bewail
# disaster
# intrusive
# preeminent
# amiabily
# hefty
# quarrellous
# disconcertingly
# selfishness
# naughty
# prohibitively
# egregiously
# corrupt
# unfortunately
# stranger
# unbiased
# taunt
# reluctance
# stagnation
# ironical
# crude
# madness
# violent
# vengefulness
# escapade
# morbid
# tiringly
# jittery
# heartily
# daring
# occlude
# handicapped
# kindness
# disinclined
# contrive
# jubilation
# blasphemy
# decisiveness
# unuseable
# exaggerate
# outrage
# scorching
# decline
# terror-genic
# maturity
# bait
# quarrellously
# shallow
# neatest
# earnestness
# depraved
# flighty
# invidiously
# judder
# accost
# prolific
# barbarity
# zest
# letch
# angrily
# lapsed
# apprehensive
# free
# exhilaratingly
# readable
# haggard
# unable
# hardened
# nourishment
# versatile
# majesty
# split
# emaciated
# defile
# apathetically
# impudence
# cheesy
# junkyard
# fictitious
# unprove
# abruptly
# senselessly
# rife
# frightful
# life-threatening
# overawe
# discouragement
# commend
# unjustly
# non-confidence
# insensitivity
# misrepresent
# monotony
# raving
# oppose
# disorderly
# prefers
# ached
# oppressively
# resent
# jarring
# gain
# unhappiness
# irrelevant
# backbone
# delectable
# uneven
# whoooa
# unfulfilled
# defamatory
# wile
# bunk
# unsteady
# spite
# sincerely
# occluding
# burn
# protective
# dishonorable
# soapy
# misbehave
# irrecoverablenesses
# shriek
# sickness
# jaw-droping
# touted
# achey
# humid
# awarded
# chafe
# eloquence
# subsidizing
# slowwww
# breeze
# misfit
# smile
# oppressive
# insurmountably
# roomy
# beneficially
# overdone
# weed
# bloody
# classic
# over-valuation
# safe
# likable
# cornerstone
# scandalously
# harmonious
# needle
# bruise
# worryingly
# disadvantageous
# leech
# lawful
# ferocity
# groundless
# stingy
# perilous
# extravagant
# lack
# uncouth
# spoilled
# upsetting
# stimulate
# enthusiasm
# gracious
# sidetrack
# misuse
# insensitive
# insignificant
# exultingly
# refined
# jollify
# daze
# glitz
# ambivalence
# trusted
# dropout
# uncertain
# demonize
# absence
# gloom
# straggler
# hazardous
# excels
# user-replaceable
# irksomeness
# sacrificed
# asininely
# savage
# ferociously
# austere
# burden
# lag
# lackluster
# depressingly
# disgust
# healthy
# stupidity
# tempting
# alarm
# contaminating
# haughty
# pleasure
# intrigue
# irretating
# disloyal
# suspect
# rapport
# ruining
# venerate
# tarnished
# trustworthiness
# top-notch
# booming
# stigmatize
# obstructing
# baseless
# heresy
# endorsed
# sarcasm
# beguile
# permissible
# divisive
# ricer
# unease
# goon
# ironically
# arrogance
# silly
# fake
# addict
# enthuse
# uplifting
# nepotism
# relentlessly
# recommend
# dissidence
# gracelessly
# peaceable
# beutifully
# rail
# egotistically
# anarchistic
# perfidious
# time-consuming
# cost-effective
# mist
# hampered
# poorest
# crazily
# distinctive
# disingenuous
# lame-duck
# waning
# nightmare
# infuriatingly
# iniquity
# prefer
# wrought
# egomania
# excessive
# distinguished
# noisy
# applaud
# freakish
# contrariness
# conspire
# playfully
# isolate
# affirm
# tenderness
# boring
# revengeful
# glorious
# aimless
# bearish
# inveigle
# suppress
# fondly
# adjustable
# deginified
# disavow
# freed
# doubtfully
# subservience
# endanger
# disabled
# grievous
# shortsighted
# adulate
# douchbag
# aggressor
# grouchy
# favored
# economical
# wound
# sensation
# inadverently
# dissatisfactory
# alarming
# catastrophic
# bravery
# misbegotten
# filthy
# anti-israeli
# loathe
# cold
# insolent
# ax
# corrupting
# imbecile
# unfriendly
# self-coup
# troublemaker
# regally
# accolade
# untenable
# degradation
# disaccord
# backache
# undercut
# famously
# exultation
# defiant
# amiable
# flaky
# fuzzy
# trust
# distraction
# dominate
# remorseful
# helping
# fresher
# scathingly
# irritably
# inordinate
# frost
# solemn
# winnable
# spinster
# genial
# surmount
# astounded
# richer
# slog
# willing
# coarse
# reprehension
# taboo
# obscured
# disheartening
# smoother
# securely
# backbiting
# worrying
# impudently
# decrement
# inattentive
# felicitous
# rip-off
# disagree
# ripped
# hated
# criticized
# miss
# snappishly
# pettifog
# kudos
# enough
# pretentious
# prefered
# stole
# excite
# torturing
# electrify
# dragging
# progress
# arduously
# trivially
# tranquil
# well-mannered
# gratitude
# bolster
# complication
# sub-par
# grate
# unappealing
# blackmail
# unlimited
# feeblely
# hasseling
# tentative
# oddest
# adventuresome
# isolation
# blame
# well-received
# lower-priced
# vigilant
# infamous
# supple
# strained
# vileness
# exasperatingly
# rock-star
# allege
# dismayingly
# elated
# inactive
# terrifically
# richly
# congested
# wreak
# bemoaning
# contradiction
# flakey
# ding
# exceed
# siege
# fantastically
# taunting
# murder
# amicable
# foolproof
# realizable
# entangle
# patience
# debase
# confounding
# right
# messy
# sloooooooooooooow
# forbidding
# peacekeeper
# startling
# shiver
# inappropriately
# flagrant
# bullish
# ingenuous
# impenitent
# dud
# lewd
# erratically
# fortuitous
# propitiously
# chic
# divisively
# verifiable
# fruitful
# incorrigible
# obtainable
# bored
# responsive
# exasperate
# drastically
# cruelty
# wripping
# staunchness
# caustic
# despairingly
# betrayer
# idolized
# incredulous
# disagreement
# domineering
# pepping
# finicky
# adamant
# murderous
# macabre
# afraid
# whip
# swanky
# excruciating
# aggravating
# greasy
# blockage
# oppression
# mendacity
# confront
# callous
# devastated
# overpower
# invective
# condemn
# lamentable
# lacking
# lamentably
# confident
# infuriated
# ineffectively
# shirk
# fierce
# urgent
# sinking
# pollute
# disappointing
# dirtbags
# uneconomical
# kindly
# drop-outs
# despotism
# inescapably
# remunerate
# attraction
# horrifys
# doubt
# overbearing
# shipwreck
# haughtily
# foully
# dislocated
# inflammation
# resurgent
# havoc
# prosper
# spewing
# downfallen
# impressiveness
# ill-sorted
# franticly
# kid-friendly
# inconvenience
# sueing
# hysteria
# struggled
# maladjusted
# reproach
# scourge
# happily
# commotion
# spoonfed
# crashed
# traped
# epidemic
# immaterial
# thrift
# interfere
# optimism
# dejection
# desertion
# passe
# liberate
# hard-liner
# qualm
# subservient
# lose
# grind
# nightmarishly
# conflicted
# stress
# facetious
# sketchy
# buoyant
# unmoved
# confess
# devoid
# restructure
# hegemony
# illuminate
# lascivious
# insolvent
# revolt
# halfhearted
# hallucinate
# worth-while
# patiently
# draconian
# rumour
# incredibly
# worth
# bent
# unfortunate
# dazed
# infamously
# displaced
# clouding
# graceful
# pathetically
# revile
# misaligns
# decadence
# appalling
# harpy
# drunken
# vindictively
# idiocy
# fatally
# debacle
# pleasing
# astonishing
# fleeing
# destiny
# effective
# protested
# disintegrated
# facilitate
# omit
# blandish
# adroit
# overtook
# slowww
# indoctrination
# saint
# filth
# loses
# deceit
# snub
# damnable
# boycott
# arbitrary
# titillate
# playful
# smudged
# sneakily
# stinging
# impersonal
# treacherous
# sputter
# grouch
# unwanted
# cohesive
# stereotypical
# adversary
# charitable
# deterioration
# slur
# discrepant
# dented
# stew
# shocking
# guidance
# scorn
# plunderer
# worry
# odder
# fruitlessly
# immobilized
# ugliness
# struggling
# retreated
# straggle
# fatuity
# blameworthy
# roadblock
# jolt
# divine
# abyss
# propaganda
# fresh
# condescending
# bugging
# sloooow
# enchantingly
# handy
# hoard
# maledict
# interesting
# fell
# impertinent
# dumbfound
# overwhelming
# recourse
# pugnaciously
# mawkishness
# severe
# enthusiastic
# slick
# hardliner
# wickedness
# calamity
# frustrated
# deviously
# bothered
# funnily
# stubborn
# thrash
# genuine
# advantageously
# listless
# emptiness
# castigate
# unproved
# strident
# halcyon
# untouched
# ftw
# perfunctory
# inhospitable
# suave
# disparaging
# glibly
# fraudulent
# thoughtlessly
# woefully
# skilled
# lambast
# killjoy
# belie
# deception
# polite
# anomaly
# affirmation
# gush
# misread
# agile
# notoriously
# unfaithfully
# beautifullly
# snappish
# reliably
# sas
# villian
# amusing
# lier
# audible
# renowned
# short-lived
# steadfastly
# argumentative
# debaser
# smartest
# buckle
# malicious
# direly
# pariah
# unsafe
# incomparable
# pamperedly
# giddy
# slooow
# berserk
# unlawful
# scummy
# doubtless
# hardball
# risky
# estranged
# inventive
# apologist
# undependability
# reward
# dick
# best-performing
# audaciously
# harridan
# unproving
# humourous
# invulnerable
# crooked
# strict
# shimmy
# losing
# disproportionate
# tense
# discomfit
# impossiblity
# scuff
# renunciation
# condemned
# darkened
# miserableness
# aspiration
# dearth
# lament
# satisfy
# demonic
# eminent
# depressed
# acerbic
# amiss
# ingenious
# cannibalize
# overdue
# contamination
# lionhearted
# dependable
# donside
# gratifying
# gravely
# tantalizing
# mournfully
# stagnate
# scandels
# tragedy
# refutes
# plasticky
# unnaturally
# laconic
# inconsolable
# fabulously
# manipulative
# straining
# fluent
# simplest
# spellbound
# harbor
# undecided
# pertinacity
# subversion
# feign
# un-viewable
# insubstantially
# invaluable
# deprive
# powerless
# malevolence
# benefit
# overpayed
# clueless
# over-acted
# fine
# unthinkable
# ambitious
# fearfully
# bash
# scoldingly
# glow
# imperil
# misconception
# hopelessness
# miscalculate
# masterful
# berate
# pessimism
# attractively
# valiantly
# two-faces
# suspicious
# consistent
# seething
# refutation
# disputed
# indecision
# solace
# fiction
# scrambled
# murderously
# laughingstock
# regal
# prompt
# dissatisfying
# dissuade
# evasive
# traitorously
# runaway
# celebration
# hottest
# disprove
# rascal
# examplary
# nebulous
# little-known
# rejuvenating
# fertile
# frustratingly
# lurk
# womanizing
# vouchsafe
# unencumbered
# best-selling
# ranting
# awful
# capability
# ignominy
# unleash
# annoys
# rebuff
# support
# neat
# mocking
# courtly
# creaking
# discriminatory
# rectifying
# smitten
# smash
# fat-cats
# worthless
# morbidly
# killed
# motivated
# unauthentic
# lousy
# serenity
# fearsome
# steady
# brand-new
# lunatic
# incapable
# obstacle
# heartbreaker
# superficial
# shortsightedness
# collusion
# enliven
# monstrous
# bitchy
# redundant
# adoringly
# unwillingness
# flawless
# cherish
# humiliating
# discontinuity
# undefined
# felicitate
# navigable
# endearing
# chide
# demoralizingly
# extoll
# windfall
# demon
# inequitable
# pretense
# err-free
# damage
# affectionate
# unlikely
# knave
# usable
# prideful
# dictatorial
# reluctant
# ambivalent
# tumultuous
# altruistic
# disdainfully
# derogatory
# fulfillment
# restored
# indiscreetly
# devilment
# detriment
# ineffectiveness
# hellion
# incorrect
# paucity
# muddy
# subversive
# optimistic
# inflammed
# involuntary
# selfishly
# obstruct
# praise
# inferiority
# spilling
# deform
# counterproductive
# victorious
# terrorize
# statuesque
# detachable
# protection
# glimmer
# ineloquent
# judders
# bogus
# sorrowfully
# fractious
# acrid
# murky
# overtaking
# astonishingly
# willingly
# loath
# wane
# unsettled
# discord
# provocation
# dungeon
# pertinacious
# dissembler
# uncomplicated
# luxuriously
# precipitate
# bedlamite
# unfairly
# chaotic
# astound
# smuttiest
# tyrant
# casualty
# inpressed
# treasure
# scarred
# bumpy
# enjoyed
# repudiate
# unity
# outrageousness
# alienated
# outrageous
# rich
# savvy
# dragoon
# furiously
# feat
# crappy
# strong
# hell-bent
# sardonically
# stall
# chivalry
# greedy
# jubilate
# eventful
# unravel
# unrelentingly
# finer
# superfluous
# hotheaded
# convience
# spook
# measly
# surreal
# deter
# incessantly
# enrapture
# admirably
# malcontent
# favour
# unsound
# slow
# sensitive
# diplomatic
# fortuitously
# dumbfounding
# distasteful
# pro
# criticism
# torturous
# thumbs-up
# penalty
# contortion
# dishearten
# confuses
# feature-rich
# unnoticed
# contend
# lengthy
# wholeheartedly
# cleaner
# senseless
# sorrow
# farce
# rejection
# infuriate
# demonized
# instantly
# gimmicked
# heavy-handed
# powerfully
# cliched
# devastation
# discomfort
# empower
# disable
# fib
# niggle
# demeaning
# far-fetched
# impartiality
# accurate
# forlornly
# menial
# flexible
# censure
# thoughtlessness
# conceited
# eye-catching
# injure
# ruthlessness
# grudge
# dawdle
# wince
# partiality
# extortion
# knife
# twinkly
# gratified
# irreparable
# retaliatory
# inflexible
# hysterical
# relish
# dismayed
# harass
# inarticulate
# noiseless
# forfeit
# falsify
# disordered
# lull
# well-managed
# botch
# pervasive
# bullyingly
# paralize
# fabrication
# facetiously
# smack
# nettle
# monster
# fallacious
# flaking
# phobia
# diabolical
# remarkably
# repression
# spectacular
# sparkle
# gumption
# amenable
# bore
# submissive
# thinner
# unavoidably
# challenging
# barren
# freedom
# fatty
# disorient
# ignore
# harmonize
# adorable
# skillfully
# privileged
# irrationality
# menacingly
# shunned
# brashly
# wack
# reprimand
# compulsive
# unproves
# browbeat
# fetid
# brutalizing
# tempt
# spade
# tortuous
# disgustedly
# obnoxious
# grieving
# proud
# premier
# degradingly
# slogging
# smoulder
# exasperating
# oppress
# auspicious
# frustrates
# restrict
# unwavering
# unspeakablely
# confidence
# sporty
# loved
# picketing
# hard-working
# contaminated
# d*mn
# guile
# hurted
# comfortable
# magnificently
# hideously
# won
# inaudible
# upscale
# insightful
# painlessly
# cynicism
# flattering
# awfulness
# talented
# devastatingly
# taint
# gained
# picky
# rift
# missed
# wreck
# skepticism
# unskilled
# lagging
# disquietingly
# hollow
# righteousness
# lowly
# gibberish
# imprisonment
# perilously
# respite
# worsening
# hardy
# irks
# undignified
# payback
# vulgar
# procrastinate
# distortion
# goof
# veritable
# detestably
# jaundiced
# successfully
# thicker
# regretfully
# supurbly
# anti-social
# defender
# weird
# precise
# jeopardize
# ravage
# efficiently
# betrays
# impiety
# respect
# inefficacy
# resentment
# honoring
# reformed
# sickeningly
# erroneous
# trick
# tired
# illogical
# correctly
# innuendo
# quiet
# problematic
# smallish
# miserable
# steadfastness
# gentlest
# pinnacle
# pitiful
# traitor
# confrontation
# remorselessness
# grace
# congestion
# grumpish
# inexplainable
# unsavory
# pessimistic
# dumbfounded
# brat
# impure
# overstates
# whore
# lugubrious
# amiability
# dashing
# motionless
# impetuous
# ill-treated
# wary
# disagreeably
# onerously
# cloudy
# scandalize
# subsidizes
# despised
# exasperated
# killer
# fanfare
# ergonomical
# well-backlit
# glum
# ghastly
# piety
# contort
# maliciously
# disturbance
# jealousness
# disconcerted
# sulk
# irksomenesses
# imposition
# personalized
# injury
# halfheartedly
# repugn
# overzealously
# accomodative
# elation
# awsome
# palatial
# contrasty
# dynamic
# admiring
# unmatched
# shiny
# chill
# faithless
# perfidity
# calumnious
# complimentary
# drowning
# recant
# inglorious
# nag
# precipitous
# gutter
# risk-free
# languid
# patronize
# standstill
# victimize
# strangely
# uncomfortably
# offensiveness
# resplendent
# miraculous
# slanderous
# repugnantly
# steep
# encroach
# extinguish
# imaginative
# pervert
# overrun
# rogue
# guilt
# absurdly
# crumples
# maltreatment
# revulsive
# congratulate
# swelling
# supporter
# gawk
# regrettable
# productively
# slowest
# reputable
# infallibly
# praising
# heaven
# superior
# rage
# congratulation
# cheating
# rupture
# wrongly
# wonderously
# simplifying
# staid
# coercion
# debaucher
# mistakenly
# accessible
# exhilaration
# deadlock
# debility
# loveless
# discontent
# masterpiece
# fucking
# brazenly
# warned
# sad
# autonomous
# abominable
# humming
# salacious
# inadvisably
# shocked
# unacceptable
# posh
# fictional
# swankiest
# damper
# regard
# one-sided
# longingly
# unprofitable
# concens
# procrastinates
# reassure
# limited
# belligerently
# humility
# vagrant
# rejoicing
# disrespect
# racist
# convoluted
# ugly
# convenience
# nervous
# snobby
# frazzled
# affluent
# calumniation
# hobble
# gold
# cringed
# sagged
# fastidious
# disorganized
# snag
# amicability
# unspecified
# extermination
# unselfish
# cataclysmal
# smear
# yay
# leverage
# ghetto
# ideal
# offend
# sagacity
# respectable
# vexingly
# envy
# plentiful
# cure
# prominent
# sharpest
# loathsomely
# impugn
# distracting
# incompetently
# disagreeing
# rusty
# inconsolably
# adversity
# displeased
# sunken
# cheated
# latency
# stupendous
# pillage
# destroy
# accomplishment
# exceled
# effusively
# tiring
# supremacy
# charmingly
# barbaric
# noxious
# happiness
# beautifully
# fussy
# beckon
# well-informed
# exhorbitant
# snappy
# authoritative
# diligently
# triumph
# ruinous
# demolish
# fatalistic
# charismatic
# discontented
# virus
# pratfall
# avid
# incendiary
# blessing
# audiciously
# grief
# dissocial
# incomprehensible
# invincible
# downcast
# lovely
# quaint
# betraying
# boiling
# tarnishing
# diabolically
# baffle
# advantageous
# foreboding
# intimidating
# fidgety
# bomb
# upheld
# stern
# scolded
# needy
# blissful
# apprehension
# glowing
# foremost
# vex
# anti-american
# upsettingly
# balanced
# pokey
# stuttering
# ineffectualness
# blasted
# treacherously
# invaluablely
# defective
# humiliation
# gaiety
# implode
# extremism
# time-honored
# irritant
# controversy
# melancholy
# undersized
# commendable
# comforting
# glower
# spoon-feed
# shame
# blurt
# importunate
# audibly
# impious
# balk
# unjustified
# ennoble
# egotism
# refinement
# laudable
# f**k
# long-lasting
# throttle
# scolding
# cheater
# unnerving
# banishment
# conspirator
# dogmatic
# bereavement
# covenant
# blinding
# prowess
# perturbed
# shaky
# fantastic
# last-ditch
# prohibitive
# scary
# fallaciousness
# sugar-coat
# indecisive
# hiliarious
# rant
# flabbergast
# unattractive
# admiringly
# shine
# achievement
# penalize
# obliterated
# scandel
# overwhelmed
# martyrdom-seeking
# bulkiness
# underpowered
# competitive
# infamy
# coldly
# brave
# wild
# wreaked
# cleanest
# enslave
# tickle
# stellarly
# notably
# object
# peacefully
# uncaring
# redeeming
# obese
# credence
# misguided
# dispiriting
# swelled
# sin
# refine
# self-interested
# desiring
# bonkers
# martyrdom
# baffling
# fallout
# shoddy
# opulent
# headway
# trivial
# persevere
# fervidly
# worsen
# traumatic
# testy
# idolize
# tidy
# exultant
# dominates
# goading
# accommodative
# inconceivably
# belabor
# fortitude
# breathlessness
# deprecate
# degeneration
# corruptted
# biased
# asinininity
# critical
# flakieness
# intelligence
# smiling
# awesome
# louder
# confusing
# famed
# ease
# threat
# wily
# frail
# unraveled
# flagging
# bloodthirsty
# low-price
# shortage
# frighteningly
# repulsiveness
# misreading
# humiliate
# occluded
# eas
# damning
# redeem
# euphoria
# undid
# irresponsibly
# unequivocally
# worried
# incredible
# reverence
# agreeable
# floored
# denies
# blindingly
# spendy
# inconsistency
# embattled
# intrusion
# glitch
# unfunded
# onerous
# master
# dote
# happier
# chatterbox
# top-quality
# subversively
# guarantee
# mawkish
# aweful
# darkness
# plight
# perversion
# fair
# excallent
# ill-tempered
# accusingly
# breaking
# pest
# victory
# stun
# intriguingly
# pure
# fusty
# inconceivable
# horrify
# sharply
# ungovernable
# brutalising
# glisten
# zombie
# matte
# harmless
# alluringly
# first-class
# caricature
# mistrust
# terribly
# inexorably
# unexpected
# leer
# antagonistic
# perversity
# resourceful
# slap
# trapped
# inconveniently
# naive
# long-winded
# embroil
# goood
# rigidness
# braggart
# innovative
# obstruction
# toll-free
# deterrent
# insultingly
# writhe
# droop
# damn
# bloom
# better-known
# gorgeously
# easy
# bewildered
# respectful
# beneficent
# downheartedly
# nitpick
# remorsefully
# pedantic
# feasibly
# damnably
# mushy
# delusional
# negate
# cry
# sty
# pleasingly
# flawlessly
# wastefulness
# overtake
# cleanliness
# scoffingly
# stuttered
# painfully
# bewilder
# keen
# well-established
# anger
# charisma
# overzealous
# fundamentalism
# shatter
# exhausted
# downfall
# glowingly
# deficient
# energy-saving
# retard
# intimidatingly
# cajole
# exagerate
# servitude
# troublesome
# dogged
# fascinate
# lawfully
# incomprehension
# lifesaver
# hindrance
# vestige
# inexpiable
# daringly
# succes
# scandalized
# foul
# ardent
# unhappily
# dotingly
# dissonant
# cheery
# mesmerized
# blotchy
# jeering
# denial
# grainy
# judicious
# molest
# lucid
# blameless
# self-serving
# amazingly
# well-intentioned
# perverted
# snarl
# suffering
# disapointed
# misrepresentation
# promise
# distress
# ob
# enthrall
# unconstitutional
# wretch
# evenly
# obscurity
# perfect
# delaying
# unlicensed
# calumniate
# liar
# wimpy
# apathy
# amaze
# irascible
# perplexed
# alarmingly
# itch
# ignorance
# undue
# sinfully
# neglect
# misguidance
# atrocity
# fancinating
# splendid
# awfully
# exuberance
# affinity
# conservative
# nastiness
# uncreative
# demolisher
# insincerely
# hasty
# volatility
# violation
# peaceful
# rivalry
# boisterous
# truant
# correct
# obsession
# devastate
# appall
# ruined
# bitingly
# refreshing
# abolish
# swift
# backwood
# friendliness
# stymied
# ominously
# bland
# impeccably
# detesting
# unseemly
# worthy
# beggar
# wallow
# awkwardness
# water-down
# offensive
# grievance
# ebulliently
# instigate
# saver
# wrong
# unabashed
# deceive
# harsh
# cleanly
# resounding
# snarky
# damaging
# lush
# radiance
# luminous
# obliterate
# versatility
# marveled
# fiasco
# excellently
# scold
# inaccurately
# relaxed
# gloatingly
# prudence
# sicken
# blasphemous
# incognizant
# flawed
# impossibly
# shrilly
# dunce
# splitting
# inadverent
# provoke
# faltered
# delirious
# flabbergasted
# dissent
# integrated
# smelt
# spookiest
# sleazy
# adulterated
# scoff
# rattled
# refusal
# vivacious
# bedlam
# viciousness
# overact
# unsuspecting
# befoul
# warm
# underestimate
# repulsing
# famous
# upbraid
# brusque
# prickle
# disillusionment
# saintly
# gutless
# bruising
# inaccuracy
# forceful
# poorer
# trustworthy
# hypocricy
# richness
# dullard
# messed
# heartfelt
# mudslinging
# counter-productive
# scariest
# swank
# unsteadiness
# precisely
# fluster
# gratification
# dispirit
# entranced
# exciting
# misgiving
# appreciatively
# reasonably
# overstated
# appreciate
# wreaks
# discourteously
# improper
# stingingly
# originality
# fatefully
# infallibility
# prison
# misbecome
# arcane
# juddering
# rremediable
# talent
# iniquitous
# outraged
# whining
# repress
# sneak
# obsessive
# afflictive
# upliftment
# backwoods
# fervently
# easiest
# intimacy
# expulse
# fecilitous
# self-humiliation
# creepy
# yawn
# blister
# aghast
# chaste
# beg
# intriguing
# depressing
# smoldering
# deadly
# amazing
# loveliness
# disgruntle
# improbability
# chore
# snagged
# womanizer
# geeky
# easier
# floundering
# overkill
# stridently
# unsteadily
# brimstone
# high-spirited
# weary
# gallant
# gentle
# enchanted
# blatantly
# degenerately
# exaltation
# interferes
# well-connected
# tolerable
# fanatically
# stunningly
# disarm
# lighter
# ordeal
# mar
# well-regarded
# dishonestly
# reprehensible
# job-killing
# imminence
# well-bred
# prosecute
# unworkable
# soft
# outcast
# bleak
# overweight
# tacky
# overpaid
# romanticize
# dump
# scare
# unwarranted
# addicting
# reassurance
# plebeian
# intransigence
# self-defeating
# deluded
# villify
# strut
# sadly
# fanatical
# hopelessly
# dejected
# disrepute
# bumpping
# endorsement
# insufficiency
# trashed
# pleased
# shockingly
# endorsing
# sneaky
# fraud
# stunt
# autocratic
# decrepit
# bargain
# irrecoverable
# goodwill
# hiss
# cataclysmic
# obstinately
# checkered
# obtrusive
# worrisome
# lambaste
# quack
# starkly
# unbelievable
# gem
# sardonic
# disagrees
# meddlesome
# amputate
# supurb
# calamitously
# criticizing
# unabashedly
# fiendish
# troublesomely
# disrespectablity
# emphatically
# rock-stars
# slanderously
# domineer
# regreted
# favorite
# splatter
# reconciliation
# slanderer
# dissident
# calumniously
# approve
# deceitfulness
# unusually
# improved
# sensational
# sunder
# seasoned
# eager
# waste
# useful
# sanctimonious
# errant
# dim
# lurid
# delightfulness
# effectual
# ill-usage
# stupidly
# dispirited
# divergent
# incitement
# ruffle
# wisdom
# disrupt
# reprove
# chagrin
# beseech
# inexorable
# eccentric
# fuck
# crueler
# agonizing
# frighten
# absurd
# marvelled
# outbreak
# knock
# insufferably
# disbeliever
# well-known
# hate
# delightfully
# dissension
# unsecure
# wicked
# kaput
# garish
# sobering
# misinform
# remorse
# generously
# puny
# ulterior
# unfeeling
# repugnant
# accessable
# unrivaled
# ugh
# encouraging
# unachievable
# qualified
# sink
# jovial
# feasible
# vibration
# levity
# addicted
# foolishness
# engrossing
# manipulation
# aggressive
# flees
# easy-to-use
# stricken
# cruelly
# disingenuously
# uncontrolled
# fleer
# maddeningly
# skittishly
# madman
# impediment
# narrower
# denied
# vibrating
# sensible
# comely
# worthwhile
# horrid
# demean
# deject
# orphan
# inefficiency
# leaky
# preferes
# intermittent
# punk
# transgress
# coward
# stammer
# debauchery
# explode
# unequal
# oppressiveness
# infringe
# profound
# stealing
# strike
# negativity
# crummy
# distorts
# rigid
# nagging
# dope
# squabbling
# distraught
# irreplaceable
# battering
# cussed
# uproot
# sly
# falsely
# reviled
# abort
# dead-on
# nefarious
# insignificantly
# all-around
# barbarian
# spiritless
# imprecision
# opponent
# dishonesty
# disinterest
# satisfactorily
# lucrative
# properly
# silent
# second-class
# imaculate
# restructuring
# fashionable
# sparkling
# indiscriminately
# apathetic
# preferring
# mediocre
# propitious
# believable
# refute
# unconvincing
# vomited
# distorted
# unwisely
# blundering
# shrew
# suspiciously
# pitifully
# brainiest
# impedance
# dizzy
# stellar
# treasonous
# soothingly
# bombardment
# hubris
# embolden
# lied
# touchy
# enhance
# venom
# frenetic
# contentment
# fearful
# awesomeness
# expensive
# tantrum
# disturbed
# mordant
# pitiable
# unthinkably
# flatteringly
# craziness
# lecher
# mystify
# glaringly
# lewdness
# savior
# sloth
# scarier
# exult
# heavyhearted
# hustler
# condescend
# insinuation
# failing
# imperialist
# benevolence
# dauntingly
# self-satisfaction
# grudging
# rigidity
# stupor
# high-priced
# horde
# crass
# strain
# insulted
# shamelessness
# rough
# despicably
# impunity
# vibrant
# diligence
# thorny
# traduce
# cannibal
# illiterate
# unilateralism
# indiscriminate
# craftly
# infernal
# pimple
# lazy
# abused
# equitable
# lorn
# thankless
# hastily
# fervor
# zealot
# first-in-class
# impartially
# aversion
# righten
# tyrannical
# passion
# inordinately
# illegally
# besiege
# screech
# bulkier
# cancerous
# puzzled
# protesting
# dissemble
# inflict
# head-aches
# dignify
# discombobulate
# mindless
# mendacious
# reverent
# effigy
# choke
# insincerity
# liberation
# laud
# incompatibility
# magical
# horrified
# aspire
# distrust
# amazement
# inimical
# suck
# unproven
# effrontery
# dying
# righteous
# invasive
# smoke
# restlessness
# openly
# superficiality
# regrettably
# zealous
# negation
# reactionary
# flak
# pardon
# suffices
# delight
# disgraceful
# exile
# striving
# prodigy
# destructive
# harried
# incapably
# unusable
# prik
# quicker
# simplistically
# overloaded
# diametrically
# unimaginable
# dissatisfy
# pretty
# illness
# vilify
# chasten
# thriving
# mesmerizes
# acclaim
# untruthful
# bungle
# licentiousness
# revolting
# bafflement
# unnatural
# toil
# sunk
# warmly
# enviably
# discountenance
# unlamentably
# bliss
# ail
# critic
# insult
# languor
# festive
# fervid
# interruption
# marvelousness
# uncompromisingly
# aggrieve
# uncooperative
# inadequate
# comfy
# reluctantly
# pampers
# dispiritedly
# fretful
# muddle
# capitulate
# alienate
# elegant
# spookier
# majestic
# unfazed
# presumptuous
# inappropriate
# expropriate
# distressed
# variety
# pinch
# prick
# bothering
# uncivilized
# humor
# remedy
# flickering
# parasite
# clear-cut
# improve
# pity
# loving
# disrespectful
# desperation
# undependable
# affection
# junky
# shemale
# immorally
# ineligible
# stunning
# adversarial
# inelegance
# insolence
# beauteous
# resound
# indulgence
# quitter
# pompous
# gauche
# remorseless
# well-made
# jealous
# deadweight
# enthralled
# stabilize
# caustically
# satisified
# purposeful
# sumptuousness
# faithfulness
# hateful
# sham
# stable
# bereft
# undissolved
# incorrectly
# unforgiving
# fawningly
# atrocious
# insufferable
# lethargic
# unforeseen
# polarisation
# blah
# stagnant
# exellent
# aggravate
# badly
# gifted
# straighten
# dissapointed
# respectfully
# misaligned
# troubling
# simplifies
# joker
# horrifying
# discourage
# cartoonish
# taxing
# jubiliant
# evocative
# angel
# squealing
# oversimplify
# insecurity
# wayward
# forged
# dishearteningly
# solid
# debilitating
# occludes
# alluring
# unemployed
# huckster
# carp
# biting
# fickle
# cutthroat
# suppression
# embroilment
# peerless
# enrichment
# bribery
# achievable
# hinder
# hoodium
# entertaining
# compact
# amuse
# dishonor
# lonely
# unimaginably
# loathing
# intelligent
# issue-free
# foolish
# eloquent
# unsatisfactory
# testily
# blather
# unsupportive
# bullshyt
# anguish
# misalign
# horrifies
# susceptible
# lavish
# indefensible
# terrific
# dumped
# inessential
# conspicuous
# exhilarate
# mistrustfully
# suspicion
# defiler
# sociable
# bragger
# revel
# skinny
# galore
# repulse
# survival
# stirringly
# misunderstand
# upgradable
# prattle
# disparage
# choleric
# succumb
# supportive
# languish
# tougher
# acrimony
# preferable
# lacked
# enthusiast
# captivate
# ho-hum
# impatience
# overture
# sh*t
# vicious
# fast-growing
# discoutinous
# sever
# impermissible
# sumptuously
# audaciousness
# cramp
# affirmative
# mourner
# rumbling
# god-send
# efficacious
# good
# poignant
# wrath
# revive
# hallowed
# enticingly
# frustrate
# defeating
# insufficiently
# accuse
# forsake
# convincingly
# desolate
# refunded
# enthral
# inconsistence
# slowly
# aggravation
# hamper
# mad
# incongruously
# transgression
# exploit
# antagonist
# deteriorating
# ghosting
# overacted
# entertains
# maladjustment
# dirty
# insubstantial
# exhort
# appreciable
# accuses
# babble
# evade
# troubled
# tawdry
# orderly
# indecently
# irredeemable
# understandable
# confounded
# ineptitude
# daunt
# warmer
# rebellious
# hail
# wrestle
# helpless
# indecorum
# valor
# sleek
# break-ups
# crept
# reproachful
# haunt
# well-educated
# tingling
# beautify
# flat-out
# exuberant
# contagious
# impressive
# indeterminable
# charm
# misdirection
# deplete
# lawbreaker
# wheedle
# abominably
# deservedly
# decay
# sued
# togetherness
# feint
# fragrant
# blab
# stylish
# deprived
# premeditated
# corrode
# exalt
# congratulatory
# gooood
# sweaty
# magnanimously
# devastates
# dense
# poorly
# simplify
# unfettered
# madly
# indecency
# earnest
# frigging
# novelty
# innocuous
# ingratitude
# adoring
# plush
# steadiness
# worriedly
# fallen
# nonexistent
# astounding
# succeed
# aching
# vexation
# tortured
# watered-down
# lech
# agonizingly
# unnervingly
# tepid
# accomplish
# repulsive
# imprison
# hype
# disturb
# myth
# junk
# needlessly
# futility
# grin
# champion
# individualized
# oblivious
# entice
# capricious
# hog
# mirage
# itching
# clean
# belittled
# tanked
# weep
# rude
# malady
# boost
# acridly
# horrendously
# mudslinger
# foolishly
# inundated
# unethical
# outsider
# misstatement
# supremely
# flourish
# unbearable
# fried
# cashback
# irragularity
# emphatic
# marginally
# falsehood
# contemptuous
# heartless
# rectify
# terribleness
# steadiest
# tentatively
# friendly
# aloof
# crushing
# idle
# recovery
# agreeably
# fatigued
# stately
# believeable
# malodorous
# timely
# admonition
# fiend
# negligence
# illogic
# delicious
# sadden
# viewable
# skeptic
# admonishment
# assuring
# disputable
# receptive
# monstrously
# daunting
# debasement
# pandemonium
# praiseworthy
# exaltingly
# phony
# scathing
# redemption
# dismally
# lucidly
# merciless
# dire
# grievously
# trendy
# plotter
# unintelligible
# deceiving
# bitch
# encroachment
# golden
# disaffirm
# underdog
# annoying
# coerce
# discouraging
# woeful
# deteriorate
# rational
# wail
# distressingly
# menace
# tamper
# undaunted
# edify
# viciously
# misleadingly
# delighted
# immoderate
# villainously
# impose
# impurity
# mischief
# belated
# secretive
# alarmed
# supporting
# wobbled
# immorality
# subvert
# neurotically
# hardhearted
# ambush
# stiffness
# worthiness
# mortifying
# geezer
# bright
# indistinguishable
# deplorably
# burning
# insatiable
# wanton
# paradise
# enjoyment
# discordance
# undercutting
# wrangle
# easygoing
# unintelligile
# savagery
# enfeeble
# harshly
# impede
# triumphantly
# nefariously
# rip
# explosive
# angriness
# laggy
# crushed
# fancy
# mischievous
# uncomfortable
# slime
# zealously
# beloved
# welcome
# approval
# slug
# plunder
# assassin
# bumping
# uproarous
# disrespectable
# smokescreen
# witty
# fearless
# rhetoric
# improves
# delicate
# skeleton
# disobedient
# unkind
# douchebag
# destitute
# vehement
# uglier
# greatness
# disavowal
# revert
# erode
# long-time
# insupportable
# decry
# shirker
# intractable
# frenzied
# paralyzed
# spiteful
# improbable
# sting
# transparent
# pepped
# imperiously
# abrasive
# virtuously
# wildly
# liked
# fat-cat
# deign
# sweetheart
# uncomfy
# rape
# demonizes
# forgetfully
# sagging
# indignation
# erratic
# spontaneous
# unavailable
# refresh
# beautiful
# unyielding
# satisfactory
# forsaken
# ironic
# faster
# drone
# imposers
# misbehavior
# flout
# avenge
# overbalance
# patriotic
# extraordinarily
# brisk
# heartbreaking
# profane
# sweeping
# peach
# disparagingly
# pointlessly
# outdone
# rampant
# ugliest
# leading
# manageable
# bestial
# exasperation
# astonish
# gaining
# knowledgeable
# tantalizingly
# scarcity
# tyranny
# spooky
# erosion
# dirtbag
# abysmally
# throbbing
# foe
# blistering
# screwy
# disquiet
# imperfect
# comprehensive
# moot
# harmful
# self-respect
# mispronounce
# difficult
# villianous
# picturesque
# contradictory
# snobbish
# slumping
# pride
# inexcusable
# spurious
# enjoy
# mature
# traction
# unlawfully
# fatique
# barbarous
# winning
# courage
# pampered
# distastefully
# presumptuously
# inflammatory
# gruff
# nitpicking
# fury
# imminently
# improperly
# priceless
# rapturously
# torturously
# astonished
# bad
# disappoint
# entrancing
# salutary
# refused
# fuss
# peace
# uphold
# grim
# revelation
# audacity
# consternation
# excellence
# pry
# stifle
# phenomenal
# best
# mispronounced
# earnestly
# wretchedness
# eloquently
# principled
# intuitive
# mournful
# endorse
# merry
# weakening
# diligent
# detested
# convincing
# idiotically
# rightly
# feebleminded
# honor
# well-wisher
# tough
# gaily
# itchy
# shrouded
# invincibility
# exuberantly
# noteworthy
# snobish
# peeve
# funky
# enhances
# world-famous
# catastrophies
# panicky
# indulge
# fav
# bristle
# aggrivation
# insincere
# deserving
# stability
# irreconcilable
# miscellaneous
# barbarously
# glistening
# instable
# misinterpret
# procrastination
# peevishly
# winner
# startle
# run-down
# enjoys
# spookily
# bashful
# inadvisable
# hardier
# sweetly
# virulence
# depress
# accusing
# radically
# undesirable
# tempest
# gorgeous
# deviate
# topnotch
# douchebags
# legendary
# euphorically
# vehemently
# awkward
# bombastic
# thirst
# succeeding
# assult
# lunaticism
# coherence
# embarrassingly
# virulent
# jutters
# scornfully
# simpler
# coercive
# luckier
# smother
# redundancy
# thwart
# vindictiveness
# painful
# breathtaking
# frozen
# decent
# restrictive
# compliment
# delinquent
# costlier
# authoritarian
# finagle
# loud
# commendably
# sturdier
# unusably
# ludicrously
# declining
# eyesore
# improving
# arrogant
# abysmal
# contention
# fan
# illicit
# crabby
# nurturing
# impaired
# demoralizing
# decency
# disoobedient
# desecrate
# layoff-happy
# nicest
# wrinkled
# unknown
# realistic
# hearten
# bizarre
# admonish
# excelent
# appealing
# incense
# polemize
# despondent
# muscle-flexing
# suavely
# stuffy
# light-hearted
# great
# exorbitant
# enjoin
# questionable
# seethe
# merriment
# anomalous
# unlucky
# poisonous
# solicitous
# incorrigibly
# pugnacious
# glut
# sustainable
# honorable
# scratched
# self-determination
# irritating
# mind-blowing
# fustigate
# innovation
# wondrous
# titillating
# mashed
# uncollectible
# brutalize
# controversial
# harmony
# pointless
# antagonize
# fastuous
# semi-retarded
# mania
# incredulously
# maniac
# dissatisfies
# drunk
# ready
# impressed
# desiccate
# odd
# dumb
# flashy
# extraneous
# racism
# merrily
# seedy
# outstrip
# cynical
# capably
# deprave
# valiant
# awe
# reckless
# jutter
# inconsequent
# adulation
# splendor
# boil
# mislike
# fails
# empathize
# inexperienced
# emergency
# numb
# importune
# embarrassing
# over-hyped
# stringently
# flee
# lifeless
# antagonism
# intoxicate
# erroneously
# optimal
# deploring
# engulf
# draining
# renewed
# lame
# remarkable
# quandary
# impulsive
# displease
# perplexing
# unwillingly
# stupidest
# mysterious
# helplessly
# enterprising
# melodramatic
# futurestic
# irreplacible
# nuisance
# ingenuously
# smut
# criminal
# brood
# wedge
# stubbornly
# colorful
# prisoner
# toxic
# mortification
# grapple
# grumpy
# sneering
# lurch
# rightness
# exalting
# cringes
# magnanimous
# lonesome
# sprightly
# doggedly
# extravagantly
# exploitation
# threatening
# inane
# slogged

# %%
print("classifying: asdg")
prob_classify = (classifier.prob_classify({"word":"asdg"}))
print(prob_classify._prob_dict)


print("classifying: good")
prob_classify = (classifier.prob_classify({"word":"good"}))
print(prob_classify._prob_dict)

print("classifying: bad")
prob_classify = (classifier.prob_classify({"positive":"bad"}))
print(prob_classify._prob_dict)
# Out:
# classifying: asdg
# {'negative': -0.6405606717984611, 'positive': -1.4798085390439812}
# classifying: good
# {'negative': -0.6405606717984611, 'positive': -1.4798085390439812}
# classifying: bad
# {'negative': -0.5081764087482131, 'positive': -1.7520026085156815}

# %%
for (label,fname) in classifier._feature_probdist:
    print(label, fname)
# Out:
# negative word
# positive word

# %%
for x in classifier._feature_probdist:
    print(x)
# Out:
# ('negative', 'word')
# ('positive', 'word')

# %%
for x in classifier._labels:
    print(x)
# Out:
# negative
# positive

# %%
prob_classify_dict = classifier.prob_classify({"word":"good"})._prob_dict
positive = prob_classify_dict["positive"]
negative = prob_classify_dict["negative"]

# %%
print(positive)
print(negative)
# Out:
# -1.4798085390439812
# -0.6405606717984611

# %%
probs = np.exp([positive, negative])/np.exp([positive, negative]).sum()

# %%
from Make_Enron_Corpus import enronCorpus
enron_corp = enronCorpus()

# %%
print(probs)
# Out:
# [0.30169322 0.69830678]

# %%
b = {}
avg_sentiment = {}
for d in enron_corp.fileids():
    b[d] = enron_corp.words(d)

# %%
for d in enron_corp.fileids():
        
        input_data = b[d]
        relation_word_feature_data = LoadAndTrainModels.applyFeatureSetToWords(input_data) 
        
        if(len(relation_word_feature_data) == 0):
            avg_sentiment[d] = [[0,0]]
        else:
            avg_sentiment[d] = []
            #total_sentiment = 0
            for feature in relation_word_feature_data:               
                prob_classify_dict = classifier.prob_classify(feature)._prob_dict
                avg_sentiment[d].append(getProbabilitiesFromLogProb(prob_classify_dict))

# %%
print("file    likelihood that file is all positive")
for file in avg_sentiment:
    #print(file)
    avg_a_prediction_for_extremes = 0
    total_prediction_for_extremes = 0
    count = 0
    
    arr = avg_sentiment[file]
    for a in arr:
        if(a[0] > .5 or a[0] < .5):
            total_prediction_for_extremes += a[0]
            count += 1
    avg_a_prediction_for_extremes = total_prediction_for_extremes/count
    print(file, " : ", avg_a_prediction_for_extremes)
# Out:
# file    likelihood that file is all positive
# 5_5.txt  :  0.2237706825635456
# 5_2.txt  :  0.22377068256350843
# 2_1.txt  :  0.2237706825635513
# 4_5.txt  :  0.22377068256353264
# 4_2.txt  :  0.22377068256355084
# 5_3.txt  :  0.22377068256350482
# 5_4.txt  :  0.22377068256353783
# 1_1.txt  :  0.22377068256355065
# 4_4.txt  :  0.22377068256353924
# 1_5.txt  :  0.22377068256350627
# 1_2.txt  :  0.2237706825635501
# 3_3.txt  :  0.0
# 2_4.txt  :  0.22377068256354354
# 4_1.txt  :  0.2237706825635092
# 3_2.txt  :  0.2237706825635018
# 3_5.txt  :  0.22377068256351143
# 1_4.txt  :  0.22377068256353536
# 5_1.txt  :  0.2237706825635423
# 2_2.txt  :  0.2237706825635476
# 2_5.txt  :  0.2237706825635422
